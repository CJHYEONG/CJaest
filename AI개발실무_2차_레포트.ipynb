# %%
# AI 개발 실무 2차 레포트
# 레벤슈타인 거리를 이용한 챗봇 구현

# 코랩에서 레벤슈타인 거리 계산 라이브러리 설치
# !pip install python-Levenshtein  # 레벤슈타인 라이브러리 설치

# 필요한 라이브러리들을 import
import pandas as pd  # CSV 파일 처리용
from sklearn.feature_extraction.text import TfidfVectorizer  # TF-IDF 벡터화
from sklearn.metrics.pairwise import cosine_similarity  # 코사인 유사도 계산
import Levenshtein  # 레벤슈타인 거리 계산

class SimpleChatBot:  # 챗봇 클래스 정의
    def __init__(self, filepath):  # 초기화 함수
        self.questions, self.answers = self.load_data(filepath)  # 데이터 로드
        self.vectorizer = TfidfVectorizer()  # TF-IDF 벡터화기 생성
        self.question_vectors = self.vectorizer.fit_transform(self.questions)  # 질문을 벡터로 변환

    def load_data(self, filepath):  # 데이터 로드 함수
        data = pd.read_csv(filepath)  # CSV 파일 읽기
        questions = data['Q'].tolist()  # 질문 컬럼을 리스트로 변환
        answers = data['A'].tolist()  # 답변 컬럼을 리스트로 변환
        return questions, answers  # 질문과 답변 리스트 반환

    def find_best_answer(self, input_sentence):  # 코사인 유사도 기반 답변 찾기
        input_vector = self.vectorizer.transform([input_sentence])  # 입력을 벡터로 변환
        similarities = cosine_similarity(input_vector, self.question_vectors)  # 유사도 계산
        best_match_index = similarities.argmax()  # 가장 유사한 인덱스 찾기
        return self.answers[best_match_index]  # 해당 답변 반환

    def find_best_answer_levenshtein(self, input_sentence):  # 레벤슈타인 거리 기반 답변 찾기
        min_distance = float('inf')  # 최소 거리 초기화
        best_match_index = 0  # 최적 인덱스 초기화

        for i, question in enumerate(self.questions):  # 모든 질문에 대해 반복
            distance = Levenshtein.distance(input_sentence, question)  # 레벤슈타인 거리 계산
            if distance < min_distance:  # 더 작은 거리 발견시
                min_distance = distance  # 최소 거리 업데이트
                best_match_index = i  # 최적 인덱스 업데이트

        return self.answers[best_match_index]  # 최적 답변 반환

# 업로드된 CSV 파일의 경로 설정
filepath = '/content/sample_data/ChatbotData.csv'  # 파일 경로 설정

# SimpleChatBot 인스턴스 생성 및 초기화
print("=== 레벤슈타인 거리 기반 챗봇 (코랩 버전) ===")  # 시작 메시지 출력
chatbot = SimpleChatBot(filepath)  # 챗봇 객체 생성

def find_most_similar_question_index(input_sentence, questions_list):  # 가장 유사한 질문 인덱스 찾기 함수
    min_distance = float('inf')  # 최소 거리 초기화
    most_similar_index = 0  # 가장 유사한 인덱스 초기화

    print(f"\n 입력 문장: '{input_sentence}'")  # 입력 문장 출력
    print("=" * 60)  # 구분선 출력

    for i, question in enumerate(questions_list):  # 모든 질문에 대해 반복
        distance = Levenshtein.distance(input_sentence, question)  # 거리 계산
        print(f"인덱스 {i}: '{question}' → 거리: {distance}")  # 각 질문별 거리 출력

        if distance < min_distance:  # 더 작은 거리 발견시
            min_distance = distance  # 최소 거리 업데이트
            most_similar_index = i  # 가장 유사한 인덱스 업데이트

    print("=" * 60)  # 구분선 출력
    print(f" 가장 유사한 질문 인덱스: {most_similar_index}")  # 결과 인덱스 출력
    print(f" 가장 유사한 질문: '{questions_list[most_similar_index]}'")  # 결과 질문 출력
    print(f" 최소 레벤슈타인 거리: {min_distance}")  # 최소 거리 출력

    return most_similar_index  # 가장 유사한 인덱스 반환

# 분석 테스트 실행
data = pd.read_csv(filepath)  # CSV 파일 읽기
questions = data['Q'].tolist()  # 질문 리스트 추출
test_input = "안녕"  # 테스트 입력 설정
result_index = find_most_similar_question_index(test_input, questions)  # 가장 유사한 질문 찾기

print("\n🎉 코랩에서 레벤슈타인 챗봇이 성공적으로 실행되었습니다!")  # 완료 메시지
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 인덱스 6829: '아따 엿먹일 방법 없나' → 거리: 12
# 인덱스 6830: '아련하게 조금씩 잊게 되나보네' → 거리: 16
# 인덱스 6831: '아름다운 사랑도 아니고 이건 뭐.' → 거리: 18
# 인덱스 6832: '아름다운 이별은 없는걸까 ㅠ' → 거리: 15
# 인덱스 6833: '아름답게 헤어지고 회사 그만둔 전남친' → 거리: 20
# 인덱스 6834: '아무 것도 할 수 없는' → 거리: 12
# 인덱스 6835: '아무것도 아닌 글에 화가 치밀어 오르네' → 거리: 21
# 인덱스 6836: '아무것도 아닌 일이 될 수 있을까' → 거리: 18
# 인덱스 6837: '아무것도 안되네' → 거리: 7
# 인덱스 6838: '아무것도 하기싫어' → 거리: 9
# 인덱스 6839: '아무도 안 놀아줘' → 거리: 8
# 인덱스 6840: '아무래도 헤어져야 할까 봐' → 거리: 14
# 인덱스 6841: '아무리 기다려도 이젠 안돌아오나봐' → 거리: 17
# 인덱스 6842: '아무리 꽉 붙들어도 무너지는건 한순간' → 거리: 20
# 인덱스 6843: '아무리 매달려도' → 거리: 8
# 인덱스 6844: '아무리 미친놈 욕을해도' → 거리: 12
# 인덱스 6845: '아무리 생각 안하려 해도' → 거리: 12
# 인덱스 6846: '아무리 힘들어도, 밥은 먹히더라구' → 거리: 18
# 인덱스 6847: '아무일도 없었던 것처럼 살고 싶어' → 거리: 18
# 인덱스 6848: '아오 그놈에 꿈' → 거리: 8
# 인덱스 6849: '아이디 생각 안나' → 거리: 8
# 인덱스 6850: '아직 그리운 그대' → 거리: 9
# 인덱스 6851: '아직 멀었나봐' → 거리: 7
# 인덱스 6852: '아직 아주 많이 사랑하는데 나는 말야' → 거리: 20
# 인덱스 6853: '아직 준비가 안됐는데.' → 거리: 11
# 인덱스 6854: '아직도 가슴이 아프고 눈물이 나네' → 거리: 18
# 인덱스 6855: '아직도 그대로인걸' → 거리: 9
# 인덱스 6856: '아직도 기억 속에 생생한데' → 거리: 14
# 인덱스 6857: '아직도 꿈같고 너무 괴로워' → 거리: 14
# 인덱스 6858: '아직도 남았나봐' → 거리: 8
# 인덱스 6859: '아직도 너무 힙듭니다.' → 거리: 12
# 인덱스 6860: '아직도 널 감싸는 내가 싫다.' → 거리: 16
# 인덱스 6861: '아직도 눈물 나' → 거리: 8
# 인덱스 6862: '아직도 많이 죽을것같아' → 거리: 12
# 인덱스 6863: '아직도 멍청하네' → 거리: 8
# 인덱스 6864: '아직도 심장이 뛰고있어.' → 거리: 13
# 인덱스 6865: '아직도 이별중인가봅니다.' → 거리: 13
# 인덱스 6866: '아직도 잊지 못하나봐' → 거리: 11
# 인덱스 6867: '아직도 잊지 못하는 사람' → 거리: 13
# 인덱스 6868: '아직도 잊지 못했는가봐' → 거리: 12
# 인덱스 6869: '아직도 잊혀지지 않아' → 거리: 11
# 인덱스 6870: '아직도 적응이 안되네' → 거리: 10
# 인덱스 6871: '아직도 헷갈리네' → 거리: 8
# 인덱스 6872: '아직도 힘들지만.' → 거리: 9
# 인덱스 6873: '아직도. 아직 인가보다.' → 거리: 13
# 인덱스 6874: '아직도잊지못했던거니' → 거리: 10
# 인덱스 6875: '아직은 아닌것 같은데' → 거리: 11
# 인덱스 6876: '아침마다 왜 이러는지' → 거리: 11
# 인덱스 6877: '아침부터 답답하네' → 거리: 9
# 인덱스 6878: '아침부터 또 눈물이 나네' → 거리: 13
# 인덱스 6879: '아침에 눈 뜨는게 힘들어' → 거리: 13
# 인덱스 6880: '아침에 벌떡 일어났네.' → 거리: 12
# 인덱스 6881: '아침이 젤 힘드네' → 거리: 9
# 인덱스 6882: '아파' → 거리: 2
# 인덱스 6883: '아프고 또 아프지만' → 거리: 10
# 인덱스 6884: '아프고 힘드네' → 거리: 7
# 인덱스 6885: '아프네' → 거리: 3
# 인덱스 6886: '아프니까 더생각나고 힘드네' → 거리: 14
# 인덱스 6887: '아프다' → 거리: 3
# 인덱스 6888: '아프지 않은 이별은 없지만, 헤어지는게 답인 관계는 있더군.' → 거리: 33
# 인덱스 6889: '아픈 상처' → 거리: 5
# 인덱스 6890: '아픈 첫사랑' → 거리: 6
# 인덱스 6891: '아픈데 연락하기 싫어' → 거리: 11
# 인덱스 6892: '아픔도 이제 안녕' → 거리: 7
# 인덱스 6893: '아픔은 덜해지는것 같은데 미련은 더욱 많아지네' → 거리: 25
# 인덱스 6894: '아픔은 빨리 잊혀지는법' → 거리: 12
# 인덱스 6895: '아픔을 지니고 사랑한다는 것' → 거리: 15
# 인덱스 6896: '아휴.' → 거리: 3
# 인덱스 6897: '아휴~ 싱숭생숭한 하루' → 거리: 12
# 인덱스 6898: '안 돌아올거 아는데' → 거리: 9
# 인덱스 6899: '안 맞는다면서 헤어진 우리' → 거리: 13
# 인덱스 6900: '안녕을 고하며' → 거리: 5
# 인덱스 6901: '안녕하세' → 거리: 2
# 인덱스 6902: '알고보니 나만 바보네' → 거리: 11
# 인덱스 6903: '알고보니 환승이별 인것 같아' → 거리: 15
# 인덱스 6904: '알수가 없네.' → 거리: 7
# 인덱스 6905: '앞으로 힘든 시간 될것같습니자' → 거리: 16
# 인덱스 6906: '앞이 캄캄합니다ㅠ' → 거리: 9
# 인덱스 6907: '애를 나혼자 키우는 것 같아' → 거리: 15
# 인덱스 6908: '애인이 생겼답니다.' → 거리: 10
# 인덱스 6909: '야' → 거리: 2
# 인덱스 6910: '야 너!' → 거리: 4
# 인덱스 6911: '야구 경기 보러 꼭 함께 가자던 그 남자' → 거리: 22
# 인덱스 6912: '야이 겁나게 미운 여자야!!' → 거리: 15
# 인덱스 6913: '약 올라' → 거리: 4
# 인덱스 6914: '약 한달 전 헤어진 그에게' → 거리: 14
# 인덱스 6915: '양가 부모가 원하지 않는다면' → 거리: 15
# 인덱스 6916: '양다리' → 거리: 3
# 인덱스 6917: '양다리? 어장관리?' → 거리: 10
# 인덱스 6918: '얘는 싸우기만 하면 연락이 안돼' → 거리: 16
# 인덱스 6919: '어느덧 이별 5주차' → 거리: 10
# 인덱스 6920: '어느덧 한달.' → 거리: 7
# 인덱스 6921: '어느덧 헤어진지도 4개월이 됐네' → 거리: 17
# 인덱스 6922: '어느새 나이가 30이네.' → 거리: 13
# 인덱스 6923: '어느새 한달인데' → 거리: 8
# 인덱스 6924: '어느새 헤어진지 한달' → 거리: 11
# 인덱스 6925: '어디까지 가야 끝이보일지' → 거리: 13
# 인덱스 6926: '어디론가 훌쩍 떠나고 싶다' → 거리: 14
# 인덱스 6927: '어디서부터 어떻게 얘기를 해야할지.' → 거리: 19
# 인덱스 6928: '어떡하지' → 거리: 4
# 인덱스 6929: '어떡해' → 거리: 3
# 인덱스 6930: '어떡해야 될가?' → 거리: 8
# 인덱스 6931: '어떤 날도, 어떤 말도' → 거리: 12
# 인덱스 6932: '어떤 놈인지 확인하고 싶으면 이상한가' → 거리: 20
# 인덱스 6933: '어떤 마음이었을까?' → 거리: 10
# 인덱스 6934: '어떤 마음인걸까' → 거리: 8
# 인덱스 6935: '어떤 작별일지' → 거리: 7
# 인덱스 6936: '어떻게 나한테 이러지' → 거리: 11
# 인덱스 6937: '어떻게 맘정리를할까?' → 거리: 11
# 인덱스 6938: '어떻게 벌주어야 할까.' → 거리: 12
# 인덱스 6939: '어떻게 살아가야 할까' → 거리: 11
# 인덱스 6940: '어떻게 하면 좋을까.' → 거리: 11
# 인덱스 6941: '어떻게 하면좋을까' → 거리: 9
# 인덱스 6942: '어떻게 해야 마음을 돌릴 수 있나' → 거리: 18
# 인덱스 6943: '어떻게 해야 여자친구가 제 진심을 알아줄까' → 거리: 23
# 인덱스 6944: '어떻게 해야 하는 거니' → 거리: 12
# 인덱스 6945: '어떻게 해야 할까?' → 거리: 10
# 인덱스 6946: '어떻게 해야돼?' → 거리: 8
# 인덱스 6947: '어떻게 헤어져' → 거리: 7
# 인덱스 6948: '어떻게 헤어져야 할지 모르겠어' → 거리: 16
# 인덱스 6949: '어떻게받아들여야할까?' → 거리: 11
# 인덱스 6950: '어떻하죠? 이 상황을' → 거리: 11
# 인덱스 6951: '어떻해야 할까' → 거리: 7
# 인덱스 6952: '어려운일' → 거리: 4
# 인덱스 6953: '어렵네' → 거리: 3
# 인덱스 6954: '어리석은 나' → 거리: 6
# 인덱스 6955: '어이 없는 헤어짐' → 거리: 9
# 인덱스 6956: '어이없는연애? 끝난걸까, 진행중일까.' → 거리: 20
# 인덱스 6957: '어제 결국 또 톡보내버렸네,' → 거리: 15
# 인덱스 6958: '어제 그녀를 또 보았어.' → 거리: 13
# 인덱스 6959: '어제 꿈에나온너.' → 거리: 9
# 인덱스 6960: '어제 만났네.' → 거리: 7
# 인덱스 6961: '어제 만났어' → 거리: 6
# 인덱스 6962: '어제 비 오는 창가를 바라보다 문득 니 생각났어' → 거리: 26
# 인덱스 6963: '어제 새벽에 그녀에게 전화가왔습니다' → 거리: 19
# 인덱스 6964: '어제 새벽에 이별했어.' → 거리: 12
# 인덱스 6965: '어제 연락 왔는데 또 상처줘서 또 헤어졌어ㅠ' → 거리: 24
# 인덱스 6966: '어제 연락이 왔어. 제가 매달려서 온거같아' → 거리: 23
# 인덱스 6967: '어제 연락햇는데ㅋㅋ' → 거리: 10
# 인덱스 6968: '어제 오늘 멘탈이 나갔네' → 거리: 13
# 인덱스 6969: '어제 이별 했습니다.' → 거리: 11
# 인덱스 6970: '어제 이별을 했는데 진짜.어이가없네.' → 거리: 20
# 인덱스 6971: '어제 이별을 했습니다' → 거리: 11
# 인덱스 6972: '어제 이별하고 맘이 너무 아파' → 거리: 16
# 인덱스 6973: '어제 이별했고, 잡고 싶은데 도와주세' → 거리: 20
# 인덱스 6974: '어제 정말 사랑한 그녀와 헤어졌습니다.' → 거리: 21
# 인덱스 6975: '어제 정말로 완전히 보냈습니다' → 거리: 16
# 인덱스 6976: '어제 헤어졌습니다' → 거리: 9
# 인덱스 6977: '어제 헤어졌어' → 거리: 7
# 인덱스 6978: '어제 헤어지자했어.' → 거리: 10
# 인덱스 6979: '어제 헤어진 여자친구 연락 왔다고 글 썼는데 ㅋㅋ' → 거리: 27
# 인덱스 6980: '어제 헤어진 여친 학교 다녀 왔어.' → 거리: 19
# 인덱스 6981: '어제가 극에 달했었는데' → 거리: 12
# 인덱스 6982: '어제가 생일이었는데.' → 거리: 11
# 인덱스 6983: '어제는 그녀의 결혼식.' → 거리: 12
# 인덱스 6984: '어제와 오늘 문득문득 생각에 눈물을 흘립니다.' → 거리: 25
# 인덱스 6985: '어제이별한 남자입니다' → 거리: 11
# 인덱스 6986: '어제전화가왔습니다' → 거리: 9
# 인덱스 6987: '어젯밤 꿈에나타났습니다' → 거리: 12
# 인덱스 6988: '어젯밤 꿈을 꿨어' → 거리: 9
# 인덱스 6989: '어젯밤 집 앞에서 잠깐 만났어.' → 거리: 17
# 인덱스 6990: '어젯밤. 헤어졌던 여자친구에게 전화가 왔어.' → 거리: 24
# 인덱스 6991: '어젯밤에 1주일 전 헤어진 여자친구 집에 찾아 갔다 왔어.' → 거리: 32
# 인덱스 6992: '어젯밤에 판도라의 상자를 열어버렸네' → 거리: 19
# 인덱스 6993: '어째서' → 거리: 3
# 인덱스 6994: '어째야 할까' → 거리: 6
# 인덱스 6995: '어쩌면 좋을까?' → 거리: 8
# 인덱스 6996: '어쩌죠' → 거리: 3
# 인덱스 6997: '어쩔 수 없겠죠' → 거리: 8
# 인덱스 6998: '어쩔수 없는' → 거리: 6
# 인덱스 6999: '어찌해야 될까?' → 거리: 8
# 인덱스 7000: '어찌해야 하나.' → 거리: 8
# 인덱스 7001: '어찌해야 할까' → 거리: 7
# 인덱스 7002: '억울한 현실' → 거리: 6
# 인덱스 7003: '억지로 붙여놓은 깨어진 도자기' → 거리: 16
# 인덱스 7004: '억지로 붙였던 깨어진 도자기의 결말' → 거리: 19
# 인덱스 7005: '언제가 제이야기 한번 들어줄 날이오겠죠?' → 거리: 22
# 인덱스 7006: '언제까지 덮을 수 있을까?' → 거리: 14
# 인덱스 7007: '언제까지 이렇게 잊지못하고 힘들기만 할까' → 거리: 22
# 인덱스 7008: '언제부터인지.' → 거리: 7
# 인덱스 7009: '언제쯤 괜찮아지려나' → 거리: 10
# 인덱스 7010: '언제쯤 괜찮아질런지.' → 거리: 11
# 인덱스 7011: '언제쯤 무뎌질까' → 거리: 8
# 인덱스 7012: '언제쯤 벗어날 수 있을까' → 거리: 13
# 인덱스 7013: '언제쯤 예쁘게 화장 잘할까' → 거리: 14
# 인덱스 7014: '언제쯤 이 끈을 놓아야할까. 지금일까.?' → 거리: 22
# 인덱스 7015: '언제쯤 잊혀질까' → 거리: 8
# 인덱스 7016: '언제쯤 잊혀질런지,,' → 거리: 11
# 인덱스 7017: '언제쯤 편히 잠들수있을까?' → 거리: 14
# 인덱스 7018: '언제쯤이면여기를' → 거리: 8
# 인덱스 7019: '언젠가 나아지겠죠?' → 거리: 10
# 인덱스 7020: '언젠가 마주치더라도 너만 보일거야.' → 거리: 19
# 인덱스 7021: '언젠가 하는 거죠' → 거리: 9
# 인덱스 7022: '언젠가는 끝' → 거리: 6
# 인덱스 7023: '언젠간 내 기억 속에서 서서히 지워지겠지.' → 거리: 23
# 인덱스 7024: '언젠간 먼저 연락오겠죠?' → 거리: 13
# 인덱스 7025: '언젠간 모두 잊고' → 거리: 9
# 인덱스 7026: '얼마나 더 지나야 아물런지' → 거리: 14
# 인덱스 7027: '얼마나 지나야 잊혀지나?' → 거리: 13
# 인덱스 7028: '얼마만큼 사랑을 받으셨나??' → 거리: 15
# 인덱스 7029: '얼마전에 욕 이빠이 하고 다 끝냈는데.' → 거리: 21
# 인덱스 7030: '엄마아빠랑 다시 같이 살아야돼' → 거리: 16
# 인덱스 7031: '업무 스트레스 넘 심해' → 거리: 12
# 인덱스 7032: '엉엉 우는꿈 꿨어' → 거리: 9
# 인덱스 7033: '에궁' → 거리: 2
# 인덱스 7034: '에라이!!!' → 거리: 6
# 인덱스 7035: '에이구 이제 그만 돌아와. 이제 그만 울고.' → 거리: 24
# 인덱스 7036: '에혀 힘드네여' → 거리: 7
# 인덱스 7037: '에휴' → 거리: 2
# 인덱스 7038: '에휴 잊기가 힘드네' → 거리: 10
# 인덱스 7039: '에휴 추억을지우네' → 거리: 9
# 인덱스 7040: '에휴 후폭풍인가봐' → 거리: 9
# 인덱스 7041: '에휴.' → 거리: 3
# 인덱스 7042: '에휴. 왤케 머리속에서 계속 멤돌까' → 거리: 19
# 인덱스 7043: '여기 글들을 보니깐' → 거리: 10
# 인덱스 7044: '여기까지 인듯 합니다.' → 거리: 12
# 인덱스 7045: '여러번 재회 그리고 헤어짐' → 거리: 14
# 인덱스 7046: '여러분 제가 느낀바입니다' → 거리: 13
# 인덱스 7047: '여섯번째 이별이에요' → 거리: 10
# 인덱스 7048: '여자 친구랑 헤어진지 23일째.' → 거리: 17
# 인덱스 7049: '여자가 떠가기전 하는 준비' → 거리: 14
# 인덱스 7050: '여자는 한번 마음 먹으면 끝인가?' → 거리: 18
# 인덱스 7051: '여자들은 바람피고 후회할까?' → 거리: 15
# 인덱스 7052: '여자사람 친구 많은 남자친구 헤어져야겠죠?' → 거리: 23
# 인덱스 7053: '여자친구 같았던 썸녀' → 거리: 11
# 인덱스 7054: '여자친구 만나고왔어~' → 거리: 11
# 인덱스 7055: '여자친구 무시했다가 이별 당했습니다.' → 거리: 20
# 인덱스 7056: '여자친구 붙잡느라고 모든걸 쏟아붓고 있습니다' → 거리: 24
# 인덱스 7057: '여자친구가 나 때매 힘들대' → 거리: 14
# 인덱스 7058: '여자친구가 왜 저랑 헤어졌는지 아직도 모르겠어' → 거리: 25
# 인덱스 7059: '여자친구랑 헤어졌네' → 거리: 10
# 인덱스 7060: '여자친구와 이별한지 정확히 1년이 되는 날이네' → 거리: 25
# 인덱스 7061: '여자친구와 헤어지고 세운 목표들' → 거리: 17
# 인덱스 7062: '여자친구와 헤어진지 8일' → 거리: 13
# 인덱스 7063: '여자친구와 헤어진지 어느덧 6개월이네,,' → 거리: 22
# 인덱스 7064: '여자친구와의 헤어짐을 막고 싶어' → 거리: 17
# 인덱스 7065: '여자친구의 거짓말' → 거리: 9
# 인덱스 7066: '여전히 괴롭다' → 거리: 7
# 인덱스 7067: '여쭈어볼것이있습니다' → 거리: 10
# 인덱스 7068: '여친 집에 있는 내 물건들이 돌아왔네' → 거리: 20
# 인덱스 7069: '여친 핸폰번호 기억못하나?' → 거리: 14
# 인덱스 7070: '여친과 갈 때까지 가면 질리나' → 거리: 16
# 인덱스 7071: '여친과의 이별' → 거리: 7
# 인덱스 7072: '여친이 드디어 권태기가 온 거 같아.' → 거리: 20
# 인덱스 7073: '여친이 찾아올 거라는 희망고문' → 거리: 16
# 인덱스 7074: '여친이랑 다툼' → 거리: 7
# 인덱스 7075: '여친이랑 헤어진지 1년째인데 아직도 못잊네.' → 거리: 24
# 인덱스 7076: '여친집에 찾아가고 싶은데 어떠하죠?' → 거리: 19
# 인덱스 7077: '여행이라도 가고싶다' → 거리: 10
# 인덱스 7078: '역시 못잊겠습니다.' → 거리: 10
# 인덱스 7079: '역시 재회는 힘들어' → 거리: 10
# 인덱스 7080: '역시나. 후폭풍이 밀려왔네' → 거리: 14
# 인덱스 7081: '연락 말라고 모질게 했내 결국' → 거리: 16
# 인덱스 7082: '연락 못하는 아픔.' → 거리: 10
# 인덱스 7083: '연락 안되서 헤어졌는데 또 연락 기다리고 있네' → 거리: 24
# 인덱스 7084: '연락 안하고 가만히 있는게 맞는 걸까?' → 거리: 20
# 인덱스 7085: '연락 왔는데 끝냈어' → 거리: 10
# 인덱스 7086: '연락올까?' → 거리: 5
# 인덱스 7087: '연락왔는데,진짜 미칠거같네' → 거리: 14
# 인덱스 7088: '연락은 괜히 해서' → 거리: 9
# 인덱스 7089: '연락을 하면 안되는구나' → 거리: 11
# 인덱스 7090: '연락을 해봤는데 안받네.' → 거리: 12
# 인덱스 7091: '연락을기다려야해? 아니면 찾아가야해?' → 거리: 20
# 인덱스 7092: '연락이 없네' → 거리: 6
# 인덱스 7093: '연락죽어도 안올텐데 매일 기다려' → 거리: 16
# 인덱스 7094: '연락처좀 바꿔 주라' → 거리: 10
# 인덱스 7095: '연락하고 싶어' → 거리: 7
# 인덱스 7096: '연락하고 싶은 충동' → 거리: 10
# 인덱스 7097: '연락하고 지내는데' → 거리: 9
# 인덱스 7098: '연락하면 후회할까' → 거리: 9
# 인덱스 7099: '연락하지 말라고 했어' → 거리: 11
# 인덱스 7100: '연락해보고싶네' → 거리: 7
# 인덱스 7101: '연락해보는게 좋을까' → 거리: 10
# 인덱스 7102: '연락했는데' → 거리: 5
# 인덱스 7103: '연락했는데 실수한거 같네' → 거리: 13
# 인덱스 7104: '연말이라 그런지' → 거리: 8
# 인덱스 7105: '연상녀랑 어제 헤어졋네' → 거리: 12
# 인덱스 7106: '연애 관계도 망' → 거리: 8
# 인덱스 7107: '연애 중 주고 받았던 문자 다시 보면 눈물이 나' → 거리: 26
# 인덱스 7108: '연애2년차.헤어졌습니다.' → 거리: 13
# 인덱스 7109: '연애하는 것도 기술이 필요한가봐' → 거리: 17
# 인덱스 7110: '연차 내고 누워만 있네' → 거리: 12
# 인덱스 7111: '연하의 남자친구와 이별 후 5일째 입니다.' → 거리: 23
# 인덱스 7112: '연휴' → 거리: 2
# 인덱스 7113: '연휴가 시작되고 나니 더 생각나네' → 거리: 18
# 인덱스 7114: '열받아서 막 전화에다가 화풀이했어' → 거리: 18
# 인덱스 7115: '영원한 사랑은 없는걸까' → 거리: 12
# 인덱스 7116: '예전 직장선배 언니가 해준이야기가 생각나네.' → 거리: 24
# 인덱스 7117: '오늘 6년이란 시간을 정리했습니다.' → 거리: 19
# 인덱스 7118: '오늘 간신히 참았어' → 거리: 10
# 인덱스 7119: '오늘 그 사람 생일이네' → 거리: 12
# 인덱스 7120: '오늘 꿈에서 그녀가 먼저 카톡 해줬어' → 거리: 20
# 인덱스 7121: '오늘 너무 힘드네' → 거리: 9
# 인덱스 7122: '오늘 다 끝냈습니다.' → 거리: 11
# 인덱스 7123: '오늘 다시만나보니 정리가될것같아' → 거리: 17
# 인덱스 7124: '오늘 다시한번 확인사살 받고왔네ㅠ' → 거리: 18
# 인덱스 7125: '오늘 더 힘이 드네' → 거리: 10
# 인덱스 7126: '오늘 따라 그 친구가 좀 보고싶네' → 거리: 18
# 인덱스 7127: '오늘 또 헤어진 사람의 sns를 봤네' → 거리: 20
# 인덱스 7128: '오늘 마지막 사진을 정리했습니다' → 거리: 17
# 인덱스 7129: '오늘 마지막 연락했습니다' → 거리: 13
# 인덱스 7130: '오늘 마지막 인사를 하러가네' → 거리: 15
# 인덱스 7131: '오늘 마지막 인사하러 갑니다.' → 거리: 16
# 인덱스 7132: '오늘 메일을 한통 보냈어' → 거리: 13
# 인덱스 7133: '오늘 무너졌어.' → 거리: 8
# 인덱스 7134: '오늘 무작정 찾으러가고싶은데 갈까?' → 거리: 19
# 인덱스 7135: '오늘 보기로 했던 그녀, 못 보았네' → 거리: 19
# 인덱스 7136: '오늘 얼굴보고 확실히 헤어졌어' → 거리: 16
# 인덱스 7137: '오늘 연락왔네 그래도 이젠 안녕' → 거리: 15
# 인덱스 7138: '오늘 연락왔어' → 거리: 7
# 인덱스 7139: '오늘 유난히 우리가 더 힘든 이유' → 거리: 18
# 인덱스 7140: '오늘 이별하러가!' → 거리: 9
# 인덱스 7141: '오늘 이별했습니다' → 거리: 9
# 인덱스 7142: '오늘 집앞까지 찾아 갔는데' → 거리: 14
# 인덱스 7143: '오늘 카톡방 나왔어 슬슬 정리하나봐' → 거리: 19
# 인덱스 7144: '오늘 편지 놓아 두려고 합니다.' → 거리: 17
# 인덱스 7145: '오늘 하루는 또 어떻게 견디죠?' → 거리: 17
# 인덱스 7146: '오늘 하루도 너없이 잘 버텼다' → 거리: 16
# 인덱스 7147: '오늘 하루도 잘 버티고 계신가?' → 거리: 17
# 인덱스 7148: '오늘 하루도 잘들 지내셨나' → 거리: 14
# 인덱스 7149: '오늘 헤어졌습니다.' → 거리: 10
# 인덱스 7150: '오늘 헤어졌어.' → 거리: 8
# 인덱스 7151: '오늘 헤어졌어여' → 거리: 8
# 인덱스 7152: '오늘 헤어짐을 말하려 합니다' → 거리: 15
# 인덱스 7153: '오늘 혼자 영화보고 왔어' → 거리: 13
# 인덱스 7154: '오늘 회사에서 어쩔수없이 보고 왔습니다' → 거리: 21
# 인덱스 7155: '오늘도 계속 생각나네' → 거리: 11
# 인덱스 7156: '오늘도 과거속에 머물며 제자리걸음이네' → 거리: 20
# 인덱스 7157: '오늘도 버티고 버팁니다' → 거리: 12
# 인덱스 7158: '오늘도 보고 왔어' → 거리: 9
# 인덱스 7159: '오늘도 술 몇 잔 마시니 생각나네요.' → 거리: 20
# 인덱스 7160: '오늘도 술마셔.' → 거리: 8
# 인덱스 7161: '오늘도 어김없이 너무생각나네' → 거리: 15
# 인덱스 7162: '오늘도 연락을 기다리는 나' → 거리: 14
# 인덱스 7163: '오늘도 연락하고싶은거 꾹.꾹 정말 참았습니다.' → 거리: 25
# 인덱스 7164: '오늘도 전 여친sns를 봤습니다' → 거리: 17
# 인덱스 7165: '오늘도 집에만 있을 예정' → 거리: 13
# 인덱스 7166: '오늘도 짝사랑하는 사람을 만나러 갑니다' → 거리: 21
# 인덱스 7167: '오늘도 출근을 합니다' → 거리: 11
# 인덱스 7168: '오늘도 톡을 보냈네' → 거리: 10
# 인덱스 7169: '오늘도 포장마차' → 거리: 8
# 인덱스 7170: '오늘도 하루 버텻구나.' → 거리: 12
# 인덱스 7171: '오늘도 하염없이 걷고 눈물 흘리고' → 거리: 18
# 인덱스 7172: '오늘도 한숨만 쉬다 하루 다 갔네' → 거리: 18
# 인덱스 7173: '오늘도잠을못이루네' → 거리: 9
# 인덱스 7174: '오늘도출근해~' → 거리: 7
# 인덱스 7175: '오늘따라 너무 연락하고 싶네.' → 거리: 16
# 인덱스 7176: '오늘따라 너무 힘드네' → 거리: 11
# 인덱스 7177: '오늘따라 더 생각나' → 거리: 10
# 인덱스 7178: '오늘따라 더 힘드네' → 거리: 10
# 인덱스 7179: '오늘따라 미치네ㅜㅜ' → 거리: 10
# 인덱스 7180: '오늘따라 보고싶다.' → 거리: 10
# 인덱스 7181: '오늘로써 이별 딱 1달째.' → 거리: 14
# 인덱스 7182: '오늘마지막 통화후 깔끔히 정리' → 거리: 16
# 인덱스 7183: '오늘만큼은 푹자고 싶은데.' → 거리: 14
# 인덱스 7184: '오늘밤 하고픈 말 다쏟아내려합니다!' → 거리: 19
# 인덱스 7185: '오늘밤은 비가 내립니다' → 거리: 12
# 인덱스 7186: '오늘부로 최악의 남자가 되었습니다' → 거리: 18
# 인덱스 7187: '오늘부터 내려놓기로 했습니다.' → 거리: 16
# 인덱스 7188: '오늘은 2년전 그녀에게 고백했던날' → 거리: 18
# 인덱스 7189: '오늘은 그런 생각이' → 거리: 10
# 인덱스 7190: '오늘은 나쁜 남자가 되기 위해 결심을 하고 있습니다.' → 거리: 29
# 인덱스 7191: '오늘은 노래한 곡에 또 울컥 ㅠ' → 거리: 17
# 인덱스 7192: '오늘은 발렌타이 데이네.' → 거리: 13
# 인덱스 7193: '오늘은 아프다' → 거리: 7
# 인덱스 7194: '오늘은 제 미련한 인생을 주절거려보렵니다.' → 거리: 23
# 인덱스 7195: '오늘의 감정일기를 써볼까 합니다' → 거리: 17
# 인덱스 7196: '오늘이 마지막 매달림입니다.' → 거리: 15
# 인덱스 7197: '오늘이 생일이네' → 거리: 8
# 인덱스 7198: '오늘이 일주일이네.' → 거리: 10
# 인덱스 7199: '오늘이 최고네' → 거리: 7
# 인덱스 7200: '오락가락하네' → 거리: 6
# 인덱스 7201: '오래 사귀다가 식어서 헤어진 남자에게도 후폭풍 있나?' → 거리: 29
# 인덱스 7202: '오래 전에 했던 이별이 생각나네' → 거리: 17
# 인덱스 7203: '오랜 연애 끝에 헤어짐을 통보 받았습니다.' → 거리: 23
# 인덱스 7204: '오랜만에 결혼한 친구 만나고 왔는데.' → 거리: 20
# 인덱스 7205: '오랜연애 환승이별' → 거리: 9
# 인덱스 7206: '오랫만에 글을 쓰네' → 거리: 10
# 인덱스 7207: '오면 안돼? 예전처럼' → 거리: 10
# 인덱스 7208: '오빠 최고라고 해주던 너' → 거리: 13
# 인덱스 7209: '오빠가 너무 보고 싶어' → 거리: 12
# 인덱스 7210: '오싹한 이야기 해줄까' → 거리: 11
# 인덱스 7211: '오해했네 그리고 차단 ㅎㅎ' → 거리: 14
# 인덱스 7212: '온라인 연애 상담해볼까' → 거리: 12
# 인덱스 7213: '온전히 내 편이길 바라는 누군가가 옆에 있었으면 좋겠는' → 거리: 30
# 인덱스 7214: '온종일 멍하네' → 거리: 7
# 인덱스 7215: '올릴까 말까 하다가 조언을 얻고자 올려봅니다.' → 거리: 25
# 인덱스 7216: '와 미친거 같네' → 거리: 8
# 인덱스 7217: '와 연락하고싶다.' → 거리: 9
# 인덱스 7218: '와 진짜 너무 짜증나네' → 거리: 12
# 인덱스 7219: '완벽한 이별 후' → 거리: 8
# 인덱스 7220: '완전 어이없네' → 거리: 7
# 인덱스 7221: '완전 헤어짐 극복 방법 있을까' → 거리: 16
# 인덱스 7222: '완전히 끝나버린 사이?' → 거리: 12
# 인덱스 7223: '완전히 끝났네' → 거리: 7
# 인덱스 7224: '완전히 끝났어~' → 거리: 8
# 인덱스 7225: '완전히 잊는다는게 쉽지 않네' → 거리: 15
# 인덱스 7226: '완전히 정리했어' → 거리: 8
# 인덱스 7227: '왔다갔다' → 거리: 4
# 인덱스 7228: '왜' → 거리: 2
# 인덱스 7229: '왜 갈수록 더 생각나지' → 거리: 12
# 인덱스 7230: '왜 그것만 삭제했을까' → 거리: 11
# 인덱스 7231: '왜 그럴까?' → 거리: 6
# 인덱스 7232: '왜 그리 쉽게 변해?' → 거리: 11
# 인덱스 7233: '왜 극복이 안되는지 제자신이 실망스러워 ㅠ' → 거리: 22
# 인덱스 7234: '왜 끝내지 못하는거죠?' → 거리: 12
# 인덱스 7235: '왜 나는 매번 이럴까' → 거리: 11
# 인덱스 7236: '왜 남자가 여자가 하는 행동을하죠?' → 거리: 19
# 인덱스 7237: '왜 남자친구 있는 여자를 내 마음을 흔들지?' → 거리: 24
# 인덱스 7238: '왜 내 블로그를 들어와서 볼까' → 거리: 16
# 인덱스 7239: '왜 못잊는거야 대체왜!' → 거리: 12
# 인덱스 7240: '왜 사람은 외로울까. 아직도 의문이다.' → 거리: 21
# 인덱스 7241: '왜 상대는 아무렇지 않은 것 같지?' → 거리: 19
# 인덱스 7242: '왜 이럴까' → 거리: 5
# 인덱스 7243: '왜 이렇게 무기력하죠' → 거리: 11
# 인덱스 7244: '왜 이별은 익숙해지지가 않을까' → 거리: 16
# 인덱스 7245: '왜 이별하고 다들 왜 연락을 끊는건가??' → 거리: 22
# 인덱스 7246: '왜 자꾸 내 마음속에 나타나니?' → 거리: 17
# 인덱스 7247: '왜 저를 좋게 기억해주는 걸까' → 거리: 16
# 인덱스 7248: '왜 차단이 안되있을까??' → 거리: 12
# 인덱스 7249: '왜그랬어?' → 거리: 5
# 인덱스 7250: '왜나만 힘든 거니' → 거리: 9
# 인덱스 7251: '왜이럴까 우린.' → 거리: 8
# 인덱스 7252: '왜이리 생각이 날까' → 거리: 10
# 인덱스 7253: '왜좋았던 기억만 남을까' → 거리: 12
# 인덱스 7254: '왠지 가슴한 켠이 먹먹하네' → 거리: 14
# 인덱스 7255: '왠지 담담하네' → 거리: 7
# 인덱스 7256: '외로운 지금 이 순간을 강해지고 있다는 생각으로 살고 싶다.' → 거리: 33
# 인덱스 7257: '외로움' → 거리: 3
# 인덱스 7258: '외로움에 연속' → 거리: 7
# 인덱스 7259: '외로움을 이겨내는 법 좀' → 거리: 13
# 인덱스 7260: '외로움이 커져.' → 거리: 8
# 인덱스 7261: '외로워' → 거리: 3
# 인덱스 7262: '외로워' → 거리: 3
# 인덱스 7263: '외로워서' → 거리: 4
# 인덱스 7264: '외롭고 우울해서 잠이쏟아져;;;' → 거리: 17
# 인덱스 7265: '외롭지만 혼자 걸을수 있어_조성모' → 거리: 18
# 인덱스 7266: '요즘 너무 고민이네' → 거리: 10
# 인덱스 7267: '요즘 노래 들으며 견디고 있어' → 거리: 16
# 인덱스 7268: '요즘 다시 쓰리다' → 거리: 9
# 인덱스 7269: '요즘따라 아침이 너무 힘드네' → 거리: 15
# 인덱스 7270: '요즘은 솔로인게 좋네~!!' → 거리: 14
# 인덱스 7271: '욕 먹을 준비 돼있다.' → 거리: 12
# 인덱스 7272: '욕까지 먹었는데 정이 안 떨어져' → 거리: 16
# 인덱스 7273: '욕을 퍼붓고 왓어' → 거리: 9
# 인덱스 7274: '용기내서 새해인사 했네' → 거리: 12
# 인덱스 7275: '용서의 의미' → 거리: 6
# 인덱스 7276: '우리 사랑은 가벼웠던 거겠죠.' → 거리: 16
# 인덱스 7277: '우리 이것만은 잊지말자' → 거리: 12
# 인덱스 7278: '우리 진짜 이별인가봐' → 거리: 11
# 인덱스 7279: '우리 추억들 모두안녕' → 거리: 9
# 인덱스 7280: '우리는 15년째 이별중입니다,' → 거리: 16
# 인덱스 7281: '우리모두 마음의여유를 가져봐' → 거리: 15
# 인덱스 7282: '우리서로 애써봐' → 거리: 8
# 인덱스 7283: '우연히 그녀를 보았습니다.' → 거리: 14
# 인덱스 7284: '우연히 길거리에 만나면 인사를 해야 하나?' → 거리: 23
# 인덱스 7285: '우연히 마주쳤어' → 거리: 8
# 인덱스 7286: '우연히, 아니 몰래 보러간 그 아이' → 거리: 19
# 인덱스 7287: '우울증 도진것 같아.' → 거리: 11
# 인덱스 7288: '우울하고 무기력해' → 거리: 9
# 인덱스 7289: '우울하네' → 거리: 4
# 인덱스 7290: '우울합니다' → 거리: 5
# 인덱스 7291: '우을증있는 여자친구' → 거리: 10
# 인덱스 7292: '우정이란게 뭘까' → 거리: 8
# 인덱스 7293: '운동 다녀왔어.' → 거리: 8
# 인덱스 7294: '운동을 통해서 극복하고 있습니다.' → 거리: 18
# 인덱스 7295: '운세 종합해 보니 헤어질 때였네' → 거리: 17
# 인덱스 7296: '운이좋은건지 나쁜건지' → 거리: 11
# 인덱스 7297: '울면서 카톡 보냈어 너무 힘들어서' → 거리: 18
# 인덱스 7298: '울적한 아침이에' → 거리: 8
# 인덱스 7299: '웃겨봐' → 거리: 3
# 인덱스 7300: '웃기지마 넌 쓰레기야' → 거리: 11
# 인덱스 7301: '웃는게 웃는게 아니네' → 거리: 11
# 인덱스 7302: '웃는척 친구인척' → 거리: 8
# 인덱스 7303: '원래 다 이런거겠죠' → 거리: 10
# 인덱스 7304: '원래 여자들은 냉정하나' → 거리: 12
# 인덱스 7305: '원래 이별하면 이런건가?' → 거리: 13
# 인덱스 7306: '원래그런건가바' → 거리: 7
# 인덱스 7307: '원래남자친구집에놀러가면청소해주나?' → 거리: 18
# 인덱스 7308: '월욜부터 힘드네.' → 거리: 9
# 인덱스 7309: '위로 받을 곳이 필요해' → 거리: 12
# 인덱스 7310: '위로 좀 해줘' → 거리: 7
# 인덱스 7311: '위로 해 주세요.' → 거리: 9
# 인덱스 7312: '위로가 되네' → 거리: 6
# 인덱스 7313: '위로가 되는 좋은글이 있어 올려' → 거리: 17
# 인덱스 7314: '위로노래' → 거리: 4
# 인덱스 7315: '위로와 격려' → 거리: 6
# 인덱스 7316: '위안이 됩니다' → 거리: 6
# 인덱스 7317: '유학간다네' → 거리: 5
# 인덱스 7318: '윤종신 '좋니' 노래 가사가 엄청 와닿네' → 거리: 22
# 인덱스 7319: '으으 짜증나네' → 거리: 7
# 인덱스 7320: '으휴 집에 들어가기가 싫네' → 거리: 14
# 인덱스 7321: '으흠' → 거리: 2
# 인덱스 7322: '음. 헤어졌는데 아직 잘 모르겠어' → 거리: 18
# 인덱스 7323: '음.반복이냐' → 거리: 6
# 인덱스 7324: '음악 들으면서 잊으려고' → 거리: 12
# 인덱스 7325: '음악이싫어졌어' → 거리: 7
# 인덱스 7326: '음여기다 말해도 될까 모르겠다' → 거리: 16
# 인덱스 7327: '응원합니다.모두들' → 거리: 9
# 인덱스 7328: '의미 부여 하면 안되겠지만' → 거리: 13
# 인덱스 7329: '의미부여' → 거리: 4
# 인덱스 7330: '의미부여 안하고 싶은데' → 거리: 11
# 인덱스 7331: '의미부여 안해야하는걸 아는데 자꾸 하게 되네ㅠ' → 거리: 24
# 인덱스 7332: '의심이 자꾸 들어' → 거리: 9
# 인덱스 7333: '의외로 병신들이 많다' → 거리: 11
# 인덱스 7334: '의욕도 업고 너무 힘들어' → 거리: 13
# 인덱스 7335: '이 가슴 먹먹함 너무 힘드네.' → 거리: 16
# 인덱스 7336: '이 글을 끝으로 잊고 싶어' → 거리: 14
# 인덱스 7337: '이 남자맘이 뭔지 ㅠ' → 거리: 11
# 인덱스 7338: '이 또한 지나가겠죠' → 거리: 10
# 인덱스 7339: '이 명절을어찌보낼지.허허' → 거리: 13
# 인덱스 7340: '이 몸쓸 놈의 마음이참 변덕스럽네' → 거리: 18
# 인덱스 7341: '이 사람은 도대체' → 거리: 9
# 인덱스 7342: '이 세상 하직할뻔 했네.' → 거리: 13
# 인덱스 7343: '이 순간 뭘하면 좋을까' → 거리: 12
# 인덱스 7344: '이 여자 유부녀인가' → 거리: 10
# 인덱스 7345: '이 여자는 무슨 생각일까' → 거리: 13
# 인덱스 7346: '이 좋은날' → 거리: 5
# 인덱스 7347: '이 행동이 절대 용납이 안돼나.?' → 거리: 17
# 인덱스 7348: '이거참 뭐하고 있는건지' → 거리: 12
# 인덱스 7349: '이건 뭘까?' → 거리: 6
# 인덱스 7350: '이건 아파도 너무 아프잖아.' → 거리: 15
# 인덱스 7351: '이건 이별을 준비해야 하는건가??' → 거리: 18
# 인덱스 7352: '이건무슨의미죠?' → 거리: 8
# 인덱스 7353: '이것 또한 받아들이는 것이겠죠~??' → 거리: 19
# 인덱스 7354: '이것도 제 미련이겠죠?' → 거리: 12
# 인덱스 7355: '이게 뭐지' → 거리: 5
# 인덱스 7356: '이게 사람 얼굴인지.' → 거리: 11
# 인덱스 7357: '이게 왜이리 힘들지' → 거리: 10
# 인덱스 7358: '이게 잠수이별인가???' → 거리: 12
# 인덱스 7359: '이기적인 마음' → 거리: 7
# 인덱스 7360: '이남자 마음을 모르겠어' → 거리: 12
# 인덱스 7361: '이대로 이별이겠죠?' → 거리: 10
# 인덱스 7362: '이러고있는게 잘하고있는건지.' → 거리: 15
# 인덱스 7363: '이러는 내가 너무 싫다' → 거리: 12
# 인덱스 7364: '이러다 병걸리겠어ㅠㅠ' → 거리: 11
# 인덱스 7365: '이러면 안되는 줄 알면서도' → 거리: 13
# 인덱스 7366: '이러면 안되는데' → 거리: 7
# 인덱스 7367: '이러지 말자' → 거리: 6
# 인덱스 7368: '이런 가사 보내는 이유가 뭘까?' → 거리: 17
# 인덱스 7369: '이런 글귀가 있네' → 거리: 9
# 인덱스 7370: '이런 날씨 우린 그렇게 만났었지' → 거리: 17
# 인덱스 7371: '이런 내가 너무 싫어' → 거리: 11
# 인덱스 7372: '이런 사랑도 있나' → 거리: 9
# 인덱스 7373: '이런 상황 어떻게 해석해야 할까?' → 거리: 18
# 인덱스 7374: '이런 생각도 맞는 생각인가?' → 거리: 15
# 인덱스 7375: '이런 여자.이런남자.안대용~' → 거리: 14
# 인덱스 7376: '이런 이별도 해 보셨나?' → 거리: 13
# 인덱스 7377: '이런 친구들이있다는 걸 다시 느끼게해준 너.' → 거리: 24
# 인덱스 7378: '이런게 연애니??' → 거리: 9
# 인덱스 7379: '이런게 후폭풍인가.' → 거리: 10
# 인덱스 7380: '이런경우.답은 나온거 같은데.' → 거리: 16
# 인덱스 7381: '이런사람을만나고싶네' → 거리: 10
# 인덱스 7382: '이런이별' → 거리: 4
# 인덱스 7383: '이런제가 싫어' → 거리: 7
# 인덱스 7384: '이럴 수가 없는데 왜이러지??' → 거리: 16
# 인덱스 7385: '이럴 수도 있구나?' → 거리: 10
# 인덱스 7386: '이럴경우 연락안오겠죠?' → 거리: 11
# 인덱스 7387: '이렇게 두번 배신하고 힘들게 할줄이야' → 거리: 20
# 인덱스 7388: '이렇게 또 끝나가나바' → 거리: 11
# 인덱스 7389: '이렇게 얘기라도 하면 나아질까?.' → 거리: 18
# 인덱스 7390: '이렇게 진짜 끝인걸까.' → 거리: 12
# 인덱스 7391: '이렇게 힘들고 괴로운 적 처음이야' → 거리: 18
# 인덱스 7392: '이만 보내줘야 할까?' → 거리: 11
# 인덱스 7393: '이무슨 신의 장난인지' → 거리: 11
# 인덱스 7394: '이미 잘못이 너무 많아서.' → 거리: 14
# 인덱스 7395: '이밤이 지나면.' → 거리: 8
# 인덱스 7396: '이번주 일요일날 만나기로 했어' → 거리: 16
# 인덱스 7397: '이번주에 혼자 여행가려 하는데' → 거리: 16
# 인덱스 7398: '이별' → 거리: 2
# 인덱스 7399: '이별 , 그 아픔을 잊는 시간의 두려움이란' → 거리: 23
# 인덱스 7400: '이별 10일째 되어가네' → 거리: 12
# 인덱스 7401: '이별 119일째,' → 거리: 9
# 인덱스 7402: '이별 20 일.' → 거리: 8
# 인덱스 7403: '이별 2달째에 새로운 소개팅했습니다.' → 거리: 20
# 인덱스 7404: '이별 2달차 아직도 못 잊고 원망' → 거리: 18
# 인덱스 7405: '이별 2일째.' → 거리: 7
# 인덱스 7406: '이별 3일째' → 거리: 6
# 인덱스 7407: '이별 400일.' → 거리: 8
# 인덱스 7408: '이별 4일차' → 거리: 6
# 인덱스 7409: '이별 5달' → 거리: 5
# 인덱스 7410: '이별 5일째' → 거리: 6
# 인덱스 7411: '이별 6개월째네' → 거리: 8
# 인덱스 7412: '이별 6개월후' → 거리: 7
# 인덱스 7413: '이별 6일째' → 거리: 6
# 인덱스 7414: '이별 6일째' → 거리: 6
# 인덱스 7415: '이별 고통' → 거리: 5
# 인덱스 7416: '이별 괜찮타.' → 거리: 7
# 인덱스 7417: '이별 극복 방법' → 거리: 8
# 인덱스 7418: '이별 극복할수있을까?' → 거리: 11
# 인덱스 7419: '이별 글 쓴지 어느 덧 1년하고 2개월 정도 되었네' → 거리: 28
# 인덱스 7420: '이별 너무 힘드네ㅠ' → 거리: 10
# 인덱스 7421: '이별 넋두리' → 거리: 6
# 인덱스 7422: '이별 다음날' → 거리: 6
# 인덱스 7423: '이별 두달째' → 거리: 6
# 인덱스 7424: '이별 뒤.' → 거리: 5
# 인덱스 7425: '이별 마음접는것은' → 거리: 9
# 인덱스 7426: '이별 받아는 들이긴했는데' → 거리: 13
# 인덱스 7427: '이별 사유가 내 맘에 안들어' → 거리: 14
# 인덱스 7428: '이별 상태.' → 거리: 6
# 인덱스 7429: '이별 성장통이 너무 길다.' → 거리: 14
# 인덱스 7430: '이별 수순을 밟고 있는 거지' → 거리: 15
# 인덱스 7431: '이별 앞에 씩씩해지기' → 거리: 11
# 인덱스 7432: '이별 왜 찾아오는 것일까?' → 거리: 14
# 인덱스 7433: '이별 이야기' → 거리: 6
# 인덱스 7434: '이별 이야기 하나' → 거리: 9
# 인덱스 7435: '이별 이야기.' → 거리: 7
# 인덱스 7436: '이별 이야기는 신중해야 하는걸 아니까 오늘도 고민합니다' → 거리: 30
# 인덱스 7437: '이별 이후.' → 거리: 6
# 인덱스 7438: '이별 일년 반' → 거리: 7
# 인덱스 7439: '이별 일주일 후 ! 우리의 이야기.' → 거리: 19
# 인덱스 7440: '이별 일주일차' → 거리: 7
# 인덱스 7441: '이별 준비' → 거리: 5
# 인덱스 7442: '이별 준비 중' → 거리: 7
# 인덱스 7443: '이별 중독' → 거리: 5
# 인덱스 7444: '이별 참 힘드네' → 거리: 8
# 인덱스 7445: '이별 통보 받은지 7일째' → 거리: 13
# 인덱스 7446: '이별 통보 후 일주일이네' → 거리: 13
# 인덱스 7447: '이별 통보를 받게 되면 어떻게 해' → 거리: 18
# 인덱스 7448: '이별 하는 중' → 거리: 7
# 인덱스 7449: '이별 하루차를 보내고 있습니다' → 거리: 16
# 인덱스 7450: '이별 한달 반째' → 거리: 8
# 인덱스 7451: '이별 한달 후.' → 거리: 8
# 인덱스 7452: '이별 한달반째' → 거리: 7
# 인덱스 7453: '이별 한달인데 가슴이 답답한게 아직도' → 거리: 20
# 인덱스 7454: '이별 한달차입니다' → 거리: 9
# 인덱스 7455: '이별 후 1년 그리고 선물' → 거리: 14
# 인덱스 7456: '이별 후 3개월이 지났는데.' → 거리: 15
# 인덱스 7457: '이별 후 6달째. 이제 그만좀 잊고 싶어' → 거리: 22
# 인덱스 7458: '이별 후 7개월,,' → 거리: 10
# 인덱스 7459: '이별 후 감정' → 거리: 7
# 인덱스 7460: '이별 후 그사람과 마주치는 거' → 거리: 16
# 인덱스 7461: '이별 후 난!' → 거리: 7
# 인덱스 7462: '이별 후 다른 이성 소개팅 후 후폭풍' → 거리: 20
# 인덱스 7463: '이별 후 다시 사귀는데 휴' → 거리: 14
# 인덱스 7464: '이별 후 두달 경과보고서' → 거리: 13
# 인덱스 7465: '이별 후 들으면 더 힘든 노래들' → 거리: 17
# 인덱스 7466: '이별 후 만남' → 거리: 7
# 인덱스 7467: '이별 후 어떻게 될까' → 거리: 11
# 인덱스 7468: '이별 후 왜 다시 전화를 하는걸까?' → 거리: 19
# 인덱스 7469: '이별 후 젤 힘들 건 허전함인 거 같아' → 거리: 21
# 인덱스 7470: '이별 후 첫날' → 거리: 7
# 인덱스 7471: '이별 후 한달' → 거리: 7
# 인덱스 7472: '이별 후 한달 경과 보고서' → 거리: 14
# 인덱스 7473: '이별 후 한달째' → 거리: 8
# 인덱스 7474: '이별 후 후회, 아쉬움' → 거리: 12
# 인덱스 7475: '이별 휴유증.' → 거리: 7
# 인덱스 7476: '이별.' → 거리: 3
# 인덱스 7477: '이별. 냉정해진다' → 거리: 9
# 인덱스 7478: '이별. 몸이 버티질 못하네.' → 거리: 15
# 인덱스 7479: '이별. 무뎌짐' → 거리: 7
# 인덱스 7480: '이별. 버릇고치기.' → 거리: 10
# 인덱스 7481: '이별. 버텨라' → 거리: 7
# 인덱스 7482: '이별. 생일이네' → 거리: 8
# 인덱스 7483: '이별. 성숙해지다' → 거리: 9
# 인덱스 7484: '이별. 지쳐버렸나' → 거리: 9
# 인덱스 7485: '이별.4주년' → 거리: 6
# 인덱스 7486: '이별.그리고 노래' → 거리: 9
# 인덱스 7487: '이별100일째.' → 거리: 8
# 인덱스 7488: '이별1년 8개월차' → 거리: 9
# 인덱스 7489: '이별6일차. 정신병자 같네.' → 거리: 15
# 인덱스 7490: '이별곧 두달.' → 거리: 7
# 인덱스 7491: '이별극복후 새로운 설렘' → 거리: 12
# 인덱스 7492: '이별까지의 이야기.' → 거리: 10
# 인덱스 7493: '이별너무 힘든네' → 거리: 8
# 인덱스 7494: '이별노래 추천해줘.' → 거리: 10
# 인덱스 7495: '이별당시 보다 더 짠한건, 나 떠났으면 잘이나 살지.' → 거리: 29
# 인덱스 7496: '이별로부터 언제쯤 자유로워질까' → 거리: 16
# 인덱스 7497: '이별만한 다이어트가 없네' → 거리: 13
# 인덱스 7498: '이별밖에 방법이 없을까?' → 거리: 13
# 인덱스 7499: '이별병.' → 거리: 4
# 인덱스 7500: '이별보다 더 아프네' → 거리: 10
# 인덱스 7501: '이별얘기 끄저그적' → 거리: 9
# 인덱스 7502: '이별에 답.' → 거리: 6
# 인덱스 7503: '이별에 힘드신 남자분들 이 글 보시고 힘내세.' → 거리: 25
# 인덱스 7504: '이별에 힘들어 하는 분들께' → 거리: 14
# 인덱스 7505: '이별에도 준비가 필요한 거겠죠?' → 거리: 17
# 인덱스 7506: '이별예감' → 거리: 4
# 인덱스 7507: '이별은 결국엔 가치의 문제네.' → 거리: 16
# 인덱스 7508: '이별은 냉정할수록 좋은 것 같아' → 거리: 17
# 인덱스 7509: '이별은 다 비슷한거 같아.' → 거리: 14
# 인덱스 7510: '이별은 받아들이는 것' → 거리: 11
# 인덱스 7511: '이별은 받아들이는 것인가' → 거리: 13
# 인덱스 7512: '이별은 받아들이는게 맞는건가보네.' → 거리: 18
# 인덱스 7513: '이별은 받아들인다는 것' → 거리: 12
# 인덱스 7514: '이별은 아니나 고민이 있습니다.' → 거리: 17
# 인덱스 7515: '이별은 역시나 힘드네.' → 거리: 12
# 인덱스 7516: '이별은 왤케 힘드나' → 거리: 10
# 인덱스 7517: '이별은 원래 힘들자나' → 거리: 11
# 인덱스 7518: '이별은 진짜 비겁한 짓 같아.' → 거리: 16
# 인덱스 7519: '이별은 필수입니다' → 거리: 9
# 인덱스 7520: '이별을 고민중입니다.' → 거리: 11
# 인덱스 7521: '이별을 극복하면서 참 많이 힘들기도 했었네.' → 거리: 24
# 인덱스 7522: '이별을 극복한건지.' → 거리: 10
# 인덱스 7523: '이별을 기다기는건지 아닌지' → 거리: 14
# 인덱스 7524: '이별을 먼저 말해본적있나??' → 거리: 15
# 인덱스 7525: '이별을 받아드리질 못하고있네' → 거리: 15
# 인덱스 7526: '이별을 받아들여야 하는데 생각이 자꾸 나네' → 거리: 23
# 인덱스 7527: '이별을 받아들이는 게 맞는걸까?' → 거리: 17
# 인덱스 7528: '이별을 받아들이지 못하는 제가 한심하네' → 거리: 21
# 인덱스 7529: '이별을 배워가는' → 거리: 8
# 인덱스 7530: '이별을 빨리 인정해야 하는데.' → 거리: 16
# 인덱스 7531: '이별을 실감하네' → 거리: 8
# 인덱스 7532: '이별을 앞둔 이들에게' → 거리: 11
# 인덱스 7533: '이별을 준비중.' → 거리: 8
# 인덱스 7534: '이별을 준비하고 있습니다 .' → 거리: 15
# 인덱스 7535: '이별을 하고.' → 거리: 7
# 인덱스 7536: '이별을 하고야 후회를 하네' → 거리: 14
# 인덱스 7537: '이별을 하는게 나을까' → 거리: 11
# 인덱스 7538: '이별을 한지 조금 지나니 후회가 되네' → 거리: 20
# 인덱스 7539: '이별을 해야하나봐' → 거리: 9
# 인덱스 7540: '이별의 고통 중에 가장 큰 건 기다림인거 같아' → 거리: 25
# 인덱스 7541: '이별의 고통 해결책.' → 거리: 11
# 인덱스 7542: '이별의 마무리' → 거리: 7
# 인덱스 7543: '이별의 순기능' → 거리: 7
# 인덱스 7544: '이별의 시간' → 거리: 6
# 인덱스 7545: '이별의 아픔 이겨내기' → 거리: 11
# 인덱스 7546: '이별의 아픔에서 벋어나는 방법' → 거리: 16
# 인덱스 7547: '이별의 아픔을 위안 삼을 방법 좀 알려줘.' → 거리: 22
# 인덱스 7548: '이별의 아픔이 있는데 몸까지 아파서야' → 거리: 20
# 인덱스 7549: '이별의 아픔이란' → 거리: 8
# 인덱스 7550: '이별의 이유는 정말 다양하내' → 거리: 15
# 인덱스 7551: '이별이 다시 올거 같은 느낌' → 거리: 15
# 인덱스 7552: '이별이 무서운건' → 거리: 8
# 인덱스 7553: '이별이 아닌 사별' → 거리: 9
# 인덱스 7554: '이별이 온 후' → 거리: 7
# 인덱스 7555: '이별이 이렇게 아픈거였나' → 거리: 13
# 인덱스 7556: '이별이 있어야 인연도 있는거 같아.' → 거리: 19
# 인덱스 7557: '이별이 좋은점' → 거리: 7
# 인덱스 7558: '이별이 코 앞으로 다가온것 같아' → 거리: 17
# 인덱스 7559: '이별이 힘든 이유는.' → 거리: 11
# 인덱스 7560: '이별이.아픈것도 슬픈것도' → 거리: 13
# 인덱스 7561: '이별이란' → 거리: 4
# 인덱스 7562: '이별이란' → 거리: 4
# 인덱스 7563: '이별이란 참 힘드네' → 거리: 10
# 인덱스 7564: '이별일까.?' → 거리: 6
# 인덱스 7565: '이별준비' → 거리: 4
# 인덱스 7566: '이별준비 그리고 극복' → 거리: 11
# 인덱스 7567: '이별준비 하려고' → 거리: 8
# 인덱스 7568: '이별준비하는방법' → 거리: 8
# 인덱스 7569: '이별중이신 회원들을 위해.' → 거리: 14
# 인덱스 7570: '이별증후군' → 거리: 5
# 인덱스 7571: '이별통보 받고 딱 일주일 째네.' → 거리: 17
# 인덱스 7572: '이별통보를 받았습니다' → 거리: 11
# 인덱스 7573: '이별하고 목숨까지 끊는 사람들 전혀 이해 못 했는데' → 거리: 28
# 인덱스 7574: '이별하고 욕했어' → 거리: 8
# 인덱스 7575: '이별하고 절대 하지 말아야할 것' → 거리: 17
# 인덱스 7576: '이별하는 방법 중' → 거리: 9
# 인덱스 7577: '이별하는게 맞는거겠죠' → 거리: 11
# 인덱스 7578: '이별하려고 하는데 정말 말 꺼내기가 힘드네' → 거리: 23
# 인덱스 7579: '이별하려고 합니다' → 거리: 9
# 인덱스 7580: '이별하려다 붙잡고 다시 사귀는데' → 거리: 17
# 인덱스 7581: '이별하신분들' → 거리: 6
# 인덱스 7582: '이별한지 10일차 점점 나아지고 있습니다.' → 거리: 23
# 인덱스 7583: '이별한지 11일째 아직은 힘드네' → 거리: 17
# 인덱스 7584: '이별한지 1년하고 2개월지나갑니다' → 거리: 18
# 인덱스 7585: '이별한지 1달' → 거리: 7
# 인덱스 7586: '이별한지 20일 차.' → 거리: 11
# 인덱스 7587: '이별한지 20일째' → 거리: 9
# 인덱스 7588: '이별한지 2달 다 되어갑니다.' → 거리: 16
# 인덱스 7589: '이별한지 2주인데' → 거리: 9
# 인덱스 7590: '이별한지 3개월' → 거리: 8
# 인덱스 7591: '이별한지 3개월 째.' → 거리: 11
# 인덱스 7592: '이별한지 3일.' → 거리: 8
# 인덱스 7593: '이별한지 3일째' → 거리: 8
# 인덱스 7594: '이별한지 3일째네' → 거리: 9
# 인덱스 7595: '이별한지 4개월째.' → 거리: 10
# 인덱스 7596: '이별한지 6년째' → 거리: 8
# 인덱스 7597: '이별한지 8일째' → 거리: 8
# 인덱스 7598: '이별한지 꽤 오래되었는데 연락이 왔네' → 거리: 20
# 인덱스 7599: '이별한지 두달이 넘고 얼굴 안본지 한달이 넘은' → 거리: 24
# 인덱스 7600: '이별한지 딱 한달 째.' → 거리: 12
# 인덱스 7601: '이별한지 벌써 한달하고 2주.' → 거리: 16
# 인덱스 7602: '이별한지 오개월째' → 거리: 9
# 인덱스 7603: '이별한지 이제 겨우 한 달' → 거리: 14
# 인덱스 7604: '이별한지 이제 일주일째네' → 거리: 13
# 인덱스 7605: '이별한지 한 달이 넘었고 괜찮은 줄 알았는데' → 거리: 24
# 인덱스 7606: '이별한지 한달된 남자입니다.' → 거리: 15
# 인덱스 7607: '이별할 때 지켜야할 매너' → 거리: 13
# 인덱스 7608: '이별할 수 없는 아픔' → 거리: 11
# 인덱스 7609: '이별할때 남자들의 거짓말' → 거리: 13
# 인덱스 7610: '이별할때는 미련 갖지 않게 해주는게 좋겠어' → 거리: 23
# 인덱스 7611: '이별해야 하나?' → 거리: 8
# 인덱스 7612: '이별했네' → 거리: 4
# 인덱스 7613: '이별했다' → 거리: 4
# 인덱스 7614: '이별했습니다' → 거리: 6
# 인덱스 7615: '이별후' → 거리: 3
# 인덱스 7616: '이별후 10개월 만의 연락. 그후.' → 거리: 19
# 인덱스 7617: '이별후 2주반이 지난시점' → 거리: 13
# 인덱스 7618: '이별후 3개월 다되가는데.' → 거리: 14
# 인덱스 7619: '이별후 3일째' → 거리: 7
# 인덱스 7620: '이별후 3주 아니 차인후 3주' → 거리: 16
# 인덱스 7621: '이별후 6개월' → 거리: 7
# 인덱스 7622: '이별후 8개월이란 시간이 흐르고' → 거리: 17
# 인덱스 7623: '이별후 그리움이 생생한 오늘' → 거리: 15
# 인덱스 7624: '이별후 너무 외로워ㅠ' → 거리: 11
# 인덱스 7625: '이별후 네달째' → 거리: 7
# 인덱스 7626: '이별후 느끼는 감정들이 단계별로 있는거 같네' → 거리: 24
# 인덱스 7627: '이별후 사진을 못지우겠네' → 거리: 13
# 인덱스 7628: '이별후 시간이 많이 흘렀네.' → 거리: 15
# 인덱스 7629: '이별후 여친페메 무슨 의미일까?' → 거리: 17
# 인덱스 7630: '이별후 열흘 뒤에 붙잡았어' → 거리: 14
# 인덱스 7631: '이별후 자주듣는 노래있으신가?' → 거리: 16
# 인덱스 7632: '이별후 재회 그리고' → 거리: 10
# 인덱스 7633: '이별후 첫 생일이네' → 거리: 10
# 인덱스 7634: '이별후 한달' → 거리: 6
# 인덱스 7635: '이별후 한달.' → 거리: 7
# 인덱스 7636: '이별후 한달반만에 그사람이 좋아하는 사람이 생겼다는걸 알아버렸네' → 거리: 35
# 인덱스 7637: '이별후 한달째 인데' → 거리: 10
# 인덱스 7638: '이별후.' → 거리: 4
# 인덱스 7639: '이별후에' → 거리: 4
# 인덱스 7640: '이별후에도 나를 괴롭히는 그의 말들' → 거리: 19
# 인덱스 7641: '이별후폭풍 왜이렇게 심하죠' → 거리: 14
# 인덱스 7642: '이사람 무슨 생각인걸까' → 거리: 12
# 인덱스 7643: '이상한나의취미.이별을세는것.' → 거리: 15
# 인덱스 7644: '이성간 종교문제' → 거리: 8
# 인덱스 7645: '이성으로는 감당 할 수 없을 것 같아' → 거리: 20
# 인덱스 7646: '이시간들 어찌보내야할까.' → 거리: 13
# 인덱스 7647: '이야기를 한번 해보려 합니다~' → 거리: 16
# 인덱스 7648: '이야기하고싶다' → 거리: 7
# 인덱스 7649: '이용당하고 버려진 느낌' → 거리: 12
# 인덱스 7650: '이용만 당했던건가' → 거리: 9
# 인덱스 7651: '이유가 확실해졌네' → 거리: 9
# 인덱스 7652: '이유라는게 뭔지' → 거리: 8
# 인덱스 7653: '이제 10일차 이별' → 거리: 10
# 인덱스 7654: '이제 1년 됐습니다' → 거리: 10
# 인덱스 7655: '이제 1년도 지나고 성큼 가을이 왔네.' → 거리: 21
# 인덱스 7656: '이제 2주 좀 넘었네' → 거리: 11
# 인덱스 7657: '이제 3개월이네' → 거리: 8
# 인덱스 7658: '이제 3주정도 되가는데 점점 좋아지고있어' → 거리: 22
# 인덱스 7659: '이제 겨우 일주일 됐네' → 거리: 12
# 인덱스 7660: '이제 괜찮습니다. 그래서 힘드네 이젠.' → 거리: 21
# 인덱스 7661: '이제 그만' → 거리: 5
# 인덱스 7662: '이제 그만 보낼려구' → 거리: 10
# 인덱스 7663: '이제 그만해야겠죠?' → 거리: 10
# 인덱스 7664: '이제 끝이네' → 거리: 6
# 인덱스 7665: '이제 끝인가봐' → 거리: 7
# 인덱스 7666: '이제 나 자신으로 돌아와 아름다워지고 싶어.' → 거리: 24
# 인덱스 7667: '이제 나도 계산적인 사람이 되려나 봅니다' → 거리: 22
# 인덱스 7668: '이제 나름의 정리를 시작해보려구.' → 거리: 18
# 인덱스 7669: '이제 너 따위 생각도 안난다 꺼져' → 거리: 17
# 인덱스 7670: '이제 너무 지쳐가네ㅠ' → 거리: 11
# 인덱스 7671: '이제 놓아 주려고' → 거리: 9
# 인덱스 7672: '이제 놓아주렵니다' → 거리: 9
# 인덱스 7673: '이제 놓을수 있을것 같아' → 거리: 13
# 인덱스 7674: '이제 누구 만나는 것도 지치네' → 거리: 16
# 인덱스 7675: '이제 더이상 남자친구로 안느껴진다는 그녀' → 거리: 21
# 인덱스 7676: '이제 때론 괜찮기도 해' → 거리: 12
# 인덱스 7677: '이제 마음 정리도 된 거 같은데' → 거리: 17
# 인덱스 7678: '이제 마음을 정리할 때가 된거같아' → 거리: 18
# 인덱스 7679: '이제 막 이별을.' → 거리: 9
# 인덱스 7680: '이제 모든게 퍼즐처럼 맞춰지네' → 거리: 16
# 인덱스 7681: '이제 반년이란 시간이 흘렀는데' → 거리: 16
# 인덱스 7682: '이제 밥도 잘 먹구 술은 안마시면 되겠는데' → 거리: 22
# 인덱스 7683: '이제 보내주려 합니다.' → 거리: 12
# 인덱스 7684: '이제 보름 다되어가네' → 거리: 11
# 인덱스 7685: '이제 사진 지운 이유는?' → 거리: 13
# 인덱스 7686: '이제 세달째' → 거리: 6
# 인덱스 7687: '이제 숨 좀 쉬나' → 거리: 9
# 인덱스 7688: '이제 스스로 인정한 것 같아' → 거리: 15
# 인덱스 7689: '이제 슬슬 끝이 보이네' → 거리: 12
# 인덱스 7690: '이제 여친이 마음이 괜잖아진거같아!!!' → 거리: 21
# 인덱스 7691: '이제 와서 소문이라니' → 거리: 11
# 인덱스 7692: '이제 이곳올일 없을거 같네하하ㅜ' → 거리: 17
# 인덱스 7693: '이제 이별한지 한달' → 거리: 10
# 인덱스 7694: '이제 인정해야할 것 같아.' → 거리: 14
# 인덱스 7695: '이제 일주일' → 거리: 6
# 인덱스 7696: '이제 일주일이네' → 거리: 8
# 인덱스 7697: '이제 잊혀지는데 속도가 붙는거 같아.' → 거리: 20
# 인덱스 7698: '이제 자리 잡아가는데' → 거리: 11
# 인덱스 7699: '이제 전부 못믿겠네.' → 거리: 11
# 인덱스 7700: '이제 점심시간에도 너에게 카톡을 할 수가 없구나.' → 거리: 27
# 인덱스 7701: '이제 정리하려고 합니다.' → 거리: 13
# 인덱스 7702: '이제 정말 끝이겠죠' → 거리: 10
# 인덱스 7703: '이제 정말 놓으려구.' → 거리: 11
# 인덱스 7704: '이제 정말 놓으려합니다' → 거리: 12
# 인덱스 7705: '이제 정말 마침표 찍어야 하네' → 거리: 16
# 인덱스 7706: '이제 제발 좀 잊자' → 거리: 10
# 인덱스 7707: '이제 진짜 끝났어 슬퍼' → 거리: 12
# 인덱스 7708: '이제 진짜 떠나야겠지' → 거리: 11
# 인덱스 7709: '이제 진짜 안녕!!' → 거리: 8
# 인덱스 7710: '이제 탈퇴합니다' → 거리: 8
# 인덱스 7711: '이제 한 삼주 되었나?' → 거리: 12
# 인덱스 7712: '이제 한달이 조금 넘었어' → 거리: 13
# 인덱스 7713: '이제 헤어진지 1주일됐어' → 거리: 13
# 인덱스 7714: '이제 헤어진지 딱 한달' → 거리: 12
# 인덱스 7715: '이제 헤이진지 5일차네.' → 거리: 13
# 인덱스 7716: '이제 확실히 알겠어' → 거리: 10
# 인덱스 7717: '이제 힘내렵니다!' → 거리: 9
# 인덱스 7718: '이제는 너를 보낼 시간이 가까이 오는구나.' → 거리: 23
# 인덱스 7719: '이제는 놓아줄꺼라 생각하지만' → 거리: 15
# 인덱스 7720: '이제는 먼저 놓아줄까 합니다' → 거리: 15
# 인덱스 7721: '이제는 숨막히고 괴로운건 좀 무뎌졌는데' → 거리: 21
# 인덱스 7722: '이제는 연락도 없는 너를 그리며' → 거리: 17
# 인덱스 7723: '이제는 이별을 받아드리려고 합니다' → 거리: 18
# 인덱스 7724: '이제는 잡을 수가 없네' → 거리: 12
# 인덱스 7725: '이제는 정리가 된 거 일까?' → 거리: 15
# 인덱스 7726: '이제는 정말 끝' → 거리: 8
# 인덱스 7727: '이제는 포기하게 되네 나 자신조차' → 거리: 18
# 인덱스 7728: '이제는 후회 없네 .' → 거리: 11
# 인덱스 7729: '이제는그만하고 싶어' → 거리: 10
# 인덱스 7730: '이제떠나려합니다' → 거리: 8
# 인덱스 7731: '이제서야 현실을 받아들이네' → 거리: 14
# 인덱스 7732: '이제서야.' → 거리: 5
# 인덱스 7733: '이제야 깨달음' → 거리: 7
# 인덱스 7734: '이제야 오래전 상대방이 아팠던걸 이해했어.' → 거리: 23
# 인덱스 7735: '이제야 좀 잊혀지네' → 거리: 10
# 인덱스 7736: '이젠 괜찮을 줄 알았어.' → 거리: 13
# 인덱스 7737: '이젠 그냥 조금만 자극이와도 눈물이.' → 거리: 20
# 인덱스 7738: '이젠 나의 스케줄로 돌아가야할때!!' → 거리: 19
# 인덱스 7739: '이젠 너 때문에 오래된 노래들도 못 듣겠어.' → 거리: 24
# 인덱스 7740: '이젠 놓아주려 해' → 거리: 9
# 인덱스 7741: '이젠 놓아줘야 할 때인가 보다' → 거리: 16
# 인덱스 7742: '이젠 눈물이 말라버렸나 봅니다.' → 거리: 17
# 인덱스 7743: '이젠 다시 만날 수도 없는 상황' → 거리: 17
# 인덱스 7744: '이젠 더이상 정 주기 무섭습니다' → 거리: 17
# 인덱스 7745: '이젠 보내줄게.' → 거리: 8
# 인덱스 7746: '이젠 붙잡을 수 도 없는 사람.' → 거리: 17
# 인덱스 7747: '이젠 슬픈 사랑' → 거리: 8
# 인덱스 7748: '이젠 어떡해얄지 모르겠어' → 거리: 13
# 인덱스 7749: '이젠 어쩌죠.' → 거리: 7
# 인덱스 7750: '이젠 유부남이 된 전남친' → 거리: 13
# 인덱스 7751: '이젠 의미있는 시간을 만들어보려해' → 거리: 18
# 인덱스 7752: '이젠 잊기로 해' → 거리: 8
# 인덱스 7753: '이젠 잡아도 안되는거래' → 거리: 11
# 인덱스 7754: '이젠 정말 놔줄라고' → 거리: 10
# 인덱스 7755: '이젠 정말 잊고 싶어' → 거리: 11
# 인덱스 7756: '이젠 정말끝이겟죠?' → 거리: 10
# 인덱스 7757: '이젠 제 자신한테 지칩니다' → 거리: 14
# 인덱스 7758: '이젠 조금씩 생각이 변하네' → 거리: 14
# 인덱스 7759: '이젠 조금씩 화가나네' → 거리: 11
# 인덱스 7760: '이젠 증오가 될거같네' → 거리: 11
# 인덱스 7761: '이젠 진짜 끝인가봐' → 거리: 10
# 인덱스 7762: '이젠 진짜 진짜 안녕' → 거리: 9
# 인덱스 7763: '이젠 포기가 되네' → 거리: 9
# 인덱스 7764: '이젠정말끝이네' → 거리: 7
# 인덱스 7765: '이틀전 그녀에게 연락이 왔습니다' → 거리: 17
# 인덱스 7766: '이해심이 부족한 나.' → 거리: 11
# 인덱스 7767: '이혼' → 거리: 2
# 인덱스 7768: '이혼만은 막고싶은데' → 거리: 10
# 인덱스 7769: '이혼을 앞둔 부부밥상' → 거리: 11
# 인덱스 7770: '이혼을 준비중인 부부라면' → 거리: 13
# 인덱스 7771: '이혼을 하고싶진 않는데 너무견디기힘듭니다 ㅠㅠ' → 거리: 25
# 인덱스 7772: '이혼한지 일년이 넘었네' → 거리: 12
# 인덱스 7773: '익숙함에 속지말자 라는말에 대하여' → 거리: 18
# 인덱스 7774: '익숙해질 법도 한데' → 거리: 10
# 인덱스 7775: '인간의 성향은 변하지 않나 봅니다.' → 거리: 19
# 인덱스 7776: '인과응보, 속이 다 시원해' → 거리: 14
# 인덱스 7777: '인내' → 거리: 2
# 인덱스 7778: '인생 포기한 걸까' → 거리: 9
# 인덱스 7779: '인연' → 거리: 2
# 인덱스 7780: '인연이었다던 그사람' → 거리: 10
# 인덱스 7781: '일과시간 후 집에 도착한 다음에도 궁상' → 거리: 21
# 인덱스 7782: '일방적인 통보로 헤어졌습니다' → 거리: 15
# 인덱스 7783: '일상의 추억' → 거리: 6
# 인덱스 7784: '일어나자마자 우울' → 거리: 9
# 인덱스 7785: '일을하다가도 잠을 자다가도' → 거리: 14
# 인덱스 7786: '일이 안 끝나' → 거리: 6
# 인덱스 7787: '일이 익숙해 지지 않네' → 거리: 12
# 인덱스 7788: '일전에 여기서 댓글주고 받던분들.' → 거리: 18
# 인덱스 7789: '일주일간 괜찮았는데.' → 거리: 11
# 인덱스 7790: '일주일이 너무 길어' → 거리: 10
# 인덱스 7791: '일주일이 일년같다' → 거리: 9
# 인덱스 7792: '일주일전까지만해도.' → 거리: 10
# 인덱스 7793: '일하는 곳 근처 가서 염탐하고 왔네.' → 거리: 20
# 인덱스 7794: '읽씹' → 거리: 2
# 인덱스 7795: '읽씹은 아프네' → 거리: 7
# 인덱스 7796: '입원 중에 이별통보 받았는데 마이 아프네' → 거리: 22
# 인덱스 7797: '입장이 바뀐 상태에서 오랜만에 와보내' → 거리: 20
# 인덱스 7798: '있을때 잘 할 걸' → 거리: 9
# 인덱스 7799: '잊겠다 다짐했는데 아직 멀었나 봅니다' → 거리: 20
# 인덱스 7800: '잊고싶다' → 거리: 4
# 인덱스 7801: '잊고싶다.' → 거리: 5
# 인덱스 7802: '잊고싶어도 잊질못하네' → 거리: 11
# 인덱스 7803: '잊고있다 생각했는데' → 거리: 10
# 인덱스 7804: '잊기가 너무 힘드네' → 거리: 10
# 인덱스 7805: '잊기가 힘듭니다.' → 거리: 9
# 인덱스 7806: '잊기싫은데 잊혀져만 가.' → 거리: 13
# 인덱스 7807: '잊기위해 무던히도노력했는데' → 거리: 14
# 인덱스 7808: '잊는다는거 참 어렵네' → 거리: 11
# 인덱스 7809: '잊어보려 하는데.' → 거리: 9
# 인덱스 7810: '잊어보려고' → 거리: 5
# 인덱스 7811: '잊어볼 마음에 다른 여자 만나고왔습니다.' → 거리: 22
# 인덱스 7812: '잊어야 살 수 있을 것 같아' → 거리: 15
# 인덱스 7813: '잊어야 할것들이 너무 많아' → 거리: 14
# 인덱스 7814: '잊어야겠지' → 거리: 5
# 인덱스 7815: '잊어야하나?' → 거리: 6
# 인덱스 7816: '잊은 줄 알았는데' → 거리: 9
# 인덱스 7817: '잊을 때.' → 거리: 5
# 인덱스 7818: '잊을 수 없다는 거 이제 알겠네' → 거리: 17
# 인덱스 7819: '잊을 수가 있을까' → 거리: 9
# 인덱스 7820: '잊을수 없는 너.' → 거리: 9
# 인덱스 7821: '잊자 잊자 지워버리자' → 거리: 11
# 인덱스 7822: '잊지 못하겟어' → 거리: 7
# 인덱스 7823: '잊지마' → 거리: 3
# 인덱스 7824: '잊지못한다면순수한겁니다' → 거리: 12
# 인덱스 7825: '잊지못할줄 알았는데' → 거리: 10
# 인덱스 7826: '잊혀져 가는게 더 아프내' → 거리: 13
# 인덱스 7827: '잊혀져가는 모든 것이 그리워지네' → 거리: 17
# 인덱스 7828: '잊혀지네.' → 거리: 5
# 인덱스 7829: '잊혀지면 얼마나 좋을가.' → 거리: 13
# 인덱스 7830: '잊혀진걸까?' → 거리: 6
# 인덱스 7831: '잊혀진다는거' → 거리: 6
# 인덱스 7832: '잊혀질까?' → 거리: 5
# 인덱스 7833: '자괴감' → 거리: 3
# 인덱스 7834: '자괴감만 드는 하루하루를 보내고 있습니다.' → 거리: 23
# 인덱스 7835: '자기 쓰레기 맞다고 잊고 살아가래' → 거리: 18
# 인덱스 7836: '자기관리가 답인듯.' → 거리: 10
# 인덱스 7837: '자기를 아껴주고 사랑해주는 사람의 마음을 이용하는 사람.' → 거리: 31
# 인덱스 7838: '자기중심적인 여자.' → 거리: 10
# 인덱스 7839: '자꾸 꿈에 나와여ㅠ ㅠ' → 거리: 12
# 인덱스 7840: '자꾸 다시 만나게 되는데 무슨 방법이 좋을까' → 거리: 24
# 인덱스 7841: '자꾸 바보짓을 하고 있네' → 거리: 13
# 인덱스 7842: '자꾸 보고싶어' → 거리: 7
# 인덱스 7843: '자꾸 봐주니까 기어오른다' → 거리: 13
# 인덱스 7844: '자꾸 생각나고 붙잡을수도 없고.' → 거리: 17
# 인덱스 7845: '자꾸 생각나네.' → 거리: 8
# 인덱스 7846: '자꾸 심하게 차였는데.생각나네' → 거리: 16
# 인덱스 7847: '자꾸 왜 사랑이 식었는지 물어보고 싶어' → 거리: 21
# 인덱스 7848: '자꾸 이상한 생각이 드네' → 거리: 13
# 인덱스 7849: '자꾸 졸게 되네' → 거리: 8
# 인덱스 7850: '자꾸 화가나' → 거리: 6
# 인덱스 7851: '자꾸 후회가 되네' → 거리: 9
# 인덱스 7852: '자는게 두려움' → 거리: 7
# 인덱스 7853: '자다가 깨서 분노' → 거리: 9
# 인덱스 7854: '자다가 이런 적은 처음이네' → 거리: 14
# 인덱스 7855: '자신과의 싸움중에서 이제 이틀째 날' → 거리: 19
# 인덱스 7856: '자신만만하던게 엊그젠데 이젠 힘들어' → 거리: 19
# 인덱스 7857: '자신을 사랑하기' → 거리: 8
# 인덱스 7858: '자신이 이해가 안될 때도 있지 않나?' → 거리: 19
# 인덱스 7859: '자야하는데~~' → 거리: 7
# 인덱스 7860: '자연스럽게 헤어진 건가?' → 거리: 13
# 인덱스 7861: '자존감이 너무 없어졌네' → 거리: 12
# 인덱스 7862: '자존감이 떨어져 있는 지금.' → 거리: 15
# 인덱스 7863: '작년오늘.' → 거리: 5
# 인덱스 7864: '작은 상처들' → 거리: 6
# 인덱스 7865: '잘 견디고있었는데' → 거리: 9
# 인덱스 7866: '잘 버텨봅시다!' → 거리: 8
# 인덱스 7867: '잘 살 수 있겠죠' → 거리: 9
# 인덱스 7868: '잘 살겠지 라고 생각하자' → 거리: 13
# 인덱스 7869: '잘 지내?' → 거리: 5
# 인덱스 7870: '잘 지내고 있네' → 거리: 8
# 인덱스 7871: '잘 지내고 있네여.아무일 없다는듯이.' → 거리: 20
# 인덱스 7872: '잘 지내니?' → 거리: 6
# 인덱스 7873: '잘 참아오고있는데' → 거리: 9
# 인덱스 7874: '잘 참았어' → 거리: 5
# 인덱스 7875: '잘 헤어졌는데 너무힘들어' → 거리: 13
# 인덱스 7876: '잘가' → 거리: 2
# 인덱스 7877: '잘못이라면 더 많이 좋아했던 죄.' → 거리: 18
# 인덱스 7878: '잘못인줄 모르는 여자' → 거리: 11
# 인덱스 7879: '잘살고있니?' → 거리: 6
# 인덱스 7880: '잘살아야 되는데' → 거리: 8
# 인덱스 7881: '잘안되는군' → 거리: 4
# 인덱스 7882: '잘지내고 있는지 궁금해지네' → 거리: 14
# 인덱스 7883: '잘지내고있니' → 거리: 6
# 인덱스 7884: '잘참다가 페북을 봐버렸네' → 거리: 13
# 인덱스 7885: '잘참아왔는데 눈물 흘렸네.' → 거리: 14
# 인덱스 7886: '잘한 행동인가 싶네' → 거리: 10
# 인덱스 7887: '잘해준것 같은데도 느끼는 미안함' → 거리: 16
# 인덱스 7888: '잘해줘도 이별은 아프네' → 거리: 12
# 인덱스 7889: '잠 들기가 무서워' → 거리: 9
# 인덱스 7890: '잠 못 이루는 어느날.' → 거리: 12
# 인덱스 7891: '잠 못자고 있네' → 거리: 8
# 인덱스 7892: '잠겨 죽어도 좋으니 너는 물처럼 내게 밀려오라.' → 거리: 26
# 인덱스 7893: '잠깐 괜찮았는데' → 거리: 8
# 인덱스 7894: '잠도 잘 못자고' → 거리: 8
# 인덱스 7895: '잠들기 직전 일어난 직후는 죽을 것 같네' → 거리: 22
# 인덱스 7896: '잠들기가 어려워' → 거리: 8
# 인덱스 7897: '잠수' → 거리: 2
# 인덱스 7898: '잠수이별' → 거리: 4
# 인덱스 7899: '잠수이별이라니!' → 거리: 8
# 인덱스 7900: '잠수이별인지 아닌지 잘 모르겠어' → 거리: 17
# 인덱스 7901: '잠수이별해도 될까' → 거리: 9
# 인덱스 7902: '잠수탄 사람' → 거리: 6
# 인덱스 7903: '잠시라도 좋으니 만낳 수 있을까' → 거리: 17
# 인덱스 7904: '잠을 많이 설치고 출근하네' → 거리: 14
# 인덱스 7905: '잠을 자야 되는데.' → 거리: 10
# 인덱스 7906: '잠이 안오네' → 거리: 5
# 인덱스 7907: '잠이 안와' → 거리: 4
# 인덱스 7908: '잡아야 되는건지 말아야 되는건지 모르겠네.' → 거리: 23
# 인덱스 7909: '잡힐듯하면서 안잡히네.' → 거리: 11
# 인덱스 7910: '장가간 그사람' → 거리: 7
# 인덱스 7911: '장거리 연애하다 이별' → 거리: 11
# 인덱스 7912: '장거리 이별' → 거리: 6
# 인덱스 7913: '장거리연애 이별' → 거리: 8
# 인덱스 7914: '장거리연애였는데' → 거리: 8
# 인덱스 7915: '장기간 연애' → 거리: 6
# 인덱스 7916: '장수 커풀의 이별' → 거리: 9
# 인덱스 7917: '재회 6개월만에 다시 헤어졌네' → 거리: 16
# 인덱스 7918: '재회 가능성이 있을까' → 거리: 11
# 인덱스 7919: '재회 그리고 다시 이별' → 거리: 12
# 인덱스 7920: '재회 네달 만에 다시 헤어집니다.' → 거리: 18
# 인덱스 7921: '재회 생각 완전히 접었습니다.' → 거리: 16
# 인덱스 7922: '재회 어떻하죠?' → 거리: 8
# 인덱스 7923: '재회 중인데 끝을내야하나 고민이됩니다' → 거리: 20
# 인덱스 7924: '재회 후 이별' → 거리: 7
# 인덱스 7925: '재회 후 이별 !' → 거리: 9
# 인덱스 7926: '재회 후 이별에는 후폭풍이 없는줄 알았는데' → 거리: 23
# 인덱스 7927: '재회 후 헤어짐.' → 거리: 9
# 인덱스 7928: '재회를 기다리다 단념하게된 이유가 뭐였나?' → 거리: 23
# 인덱스 7929: '재회를 바라는것도 새로운 사랑을 원하는것도 아닌데.' → 거리: 28
# 인덱스 7930: '재회를 위한 기다림' → 거리: 10
# 인덱스 7931: '재회를 하긴 했었는데' → 거리: 11
# 인덱스 7932: '재회를 한다해도' → 거리: 8
# 인덱스 7933: '재회하고 딱5개월만에 헤어졌네' → 거리: 16
# 인덱스 7934: '재회하고싶어' → 거리: 6
# 인덱스 7935: '재회하면 또 그렇겠지' → 거리: 11
# 인덱스 7936: '재회했는데 행복하지 않네' → 거리: 13
# 인덱스 7937: '재회했다가 이별 .' → 거리: 10
# 인덱스 7938: '재회후 다시 이별' → 거리: 9
# 인덱스 7939: '재회후 또 이별' → 거리: 8
# 인덱스 7940: '저 괜찮으면 친구사이 하자는데' → 거리: 16
# 인덱스 7941: '저 사람이 왜 자꾸 볼까?' → 거리: 14
# 인덱스 7942: '저 잘 잊을 수 있겠죠?' → 거리: 13
# 인덱스 7943: '저는 4시간에 걸쳐서 정리를 했습니다' → 거리: 20
# 인덱스 7944: '저는 개인적으로 따로 연락하자는분들.' → 거리: 20
# 인덱스 7945: '저는 어떻게 해야할까여???' → 거리: 15
# 인덱스 7946: '저는 이별하면 남자만 힘든 줄 알았어요.' → 거리: 22
# 인덱스 7947: '저는 이제 포기할라구' → 거리: 11
# 인덱스 7948: '저는 전 여친 관련해서 거의 모든걸 다 지웠어' → 거리: 25
# 인덱스 7949: '저도 가슴 아픈 이별을 했습니다.' → 거리: 18
# 인덱스 7950: '저도 어쩔 수 없는 찌질한 남자인가 봅니다.' → 거리: 24
# 인덱스 7951: '저도 연애하고 결혼할 수 있을까' → 거리: 17
# 인덱스 7952: '저만 이렇게 힘든거 아니죠 ㅠㅠ?' → 거리: 18
# 인덱스 7953: '저만 힘든 것 같아요' → 거리: 11
# 인덱스 7954: '저에게 희망이 있을까?' → 거리: 12
# 인덱스 7955: '저주스럽다 모든게 다' → 거리: 11
# 인덱스 7956: '적응이 안되네.' → 거리: 7
# 인덱스 7957: '전 결국 밑바닥까지 보고말았습니다' → 거리: 18
# 인덱스 7958: '전 기다리고 있어.' → 거리: 10
# 인덱스 7959: '전 바보입니다.' → 거리: 8
# 인덱스 7960: '전 병신인가봅니다.' → 거리: 10
# 인덱스 7961: '전 여자친구' → 거리: 6
# 인덱스 7962: '전 여자친구 부친상 다녀왔어' → 거리: 15
# 인덱스 7963: '전 여자친구가 마지막으로 얼굴 한 번만 보자고' → 거리: 25
# 인덱스 7964: '전 여자친구가 카톡 친추에 떴어' → 거리: 17
# 인덱스 7965: '전 여자친구의 새 남자친구.' → 거리: 15
# 인덱스 7966: '전 여자친구한테 남자가 생긴 거 같아' → 거리: 20
# 인덱스 7967: '전 여친 생일이야' → 거리: 9
# 인덱스 7968: '전 여친 카톡 메인 사진 슬프다' → 거리: 17
# 인덱스 7969: '전 여친 카톡 메인 프로필.' → 거리: 15
# 인덱스 7970: '전 여친에게 카톡 보내는 꿈 꿨어' → 거리: 18
# 인덱스 7971: '전 여친이 드디어 연애를 시작했네.' → 거리: 19
# 인덱스 7972: '전 여친이 페북 연애중 띄웠었다네' → 거리: 18
# 인덱스 7973: '전 왜 이렇게 안똑똑할까요?' → 거리: 14
# 인덱스 7974: '전 왜 짧은 연애만 반복될까?' → 거리: 16
# 인덱스 7975: '전 정말괜찮은데' → 거리: 8
# 인덱스 7976: '전 제가 찬건 줄 알았는데' → 거리: 14
# 인덱스 7977: '전 헤어지고 곧장 소개팅을 했죠.' → 거리: 18
# 인덱스 7978: '전남자친구 생일' → 거리: 8
# 인덱스 7979: '전남친 마주쳤어' → 거리: 8
# 인덱스 7980: '전남친 여친 생겼네' → 거리: 10
# 인덱스 7981: '전남친 집앞' → 거리: 6
# 인덱스 7982: '전남친 트라우마에 힘들어하는 여자친구.' → 거리: 21
# 인덱스 7983: '전남친 후폭풍 온거 같을때' → 거리: 14
# 인덱스 7984: '전남친소식을들었어' → 거리: 9
# 인덱스 7985: '전남친에게 연락왔어.' → 거리: 11
# 인덱스 7986: '전남친이 만나자고 합니다.' → 거리: 14
# 인덱스 7987: '전남친이 톡 차단했더라구' → 거리: 13
# 인덱스 7988: '전남친한테 한달만에 연락하고싶어 ㅠㅠ' → 거리: 20
# 인덱스 7989: '전여자친구 잊고 사랑하는법.' → 거리: 15
# 인덱스 7990: '전여친' → 거리: 3
# 인덱스 7991: '전여친 꿈을 꿧어' → 거리: 9
# 인덱스 7992: '전여친 남자 생겼나 봐' → 거리: 12
# 인덱스 7993: '전여친 최악입니다' → 거리: 9
# 인덱스 7994: '전여친 카톡 탈퇴 재가입 한거 같은데' → 거리: 20
# 인덱스 7995: '전여친 한테 두달만에 연락이 왔어.' → 거리: 19
# 인덱스 7996: '전여친 헤어졌으니 남이죠?' → 거리: 14
# 인덱스 7997: '전여친생일 ㅎㅎ' → 거리: 8
# 인덱스 7998: '전여친에게 다시 연락이 오면' → 거리: 15
# 인덱스 7999: '전여친은 남자가 벌써 생겼네' → 거리: 15
# 인덱스 8000: '전여친이 나보다 나은 사람이라는 생각이 자꾸 들어' → 거리: 27
# 인덱스 8001: '전여친이랑 낼 술한잔 하기로 했어' → 거리: 18
# 인덱스 8002: '전여친한테 남친이 생겼네' → 거리: 13
# 인덱스 8003: '전하지 못 할 편지' → 거리: 10
# 인덱스 8004: '전화가 왔는데 못받앗어' → 거리: 12
# 인덱스 8005: '전화하고싶어' → 거리: 6
# 인덱스 8006: '절대 사과 안하는 여자친구' → 거리: 13
# 인덱스 8007: '절망적인데' → 거리: 5
# 인덱스 8008: '점심시간잠깐 그녀가 저에게 했던 말들이 떠오르네~ㅠㅠ' → 거리: 29
# 인덱스 8009: '점점 괜찮아 지는것 같다가도.' → 거리: 16
# 인덱스 8010: '점점 나도 지쳐가네.' → 거리: 11
# 인덱스 8011: '점점 나아진다. 머리로 정리하니 마음도 이제 따라온다.' → 거리: 30
# 인덱스 8012: '점점 더 심해지는듯' → 거리: 10
# 인덱스 8013: '점점 힘들어져' → 거리: 7
# 인덱스 8014: '정리가 도저히안됩니다지금도 그여자집앞' → 거리: 19
# 인덱스 8015: '정리가 되네' → 거리: 6
# 인덱스 8016: '정리되지 못한 이별' → 거리: 10
# 인덱스 8017: '정리하는 중' → 거리: 6
# 인덱스 8018: '정리해야지' → 거리: 5
# 인덱스 8019: '정말 . 냉정하네' → 거리: 9
# 인덱스 8020: '정말 간절하고 간절하네' → 거리: 12
# 인덱스 8021: '정말 구제불능에 멍청이 인가봐' → 거리: 16
# 인덱스 8022: '정말 꿈같다.' → 거리: 7
# 인덱스 8023: '정말 끝까지 저의 마지막 자존심마저 뭉개버리네' → 거리: 25
# 인덱스 8024: '정말 끝이라고' → 거리: 7
# 인덱스 8025: '정말 난감하다' → 거리: 7
# 인덱스 8026: '정말 너를 받아준게 아니였어.ㅠㅠ' → 거리: 18
# 인덱스 8027: '정말 너무 궁금해' → 거리: 9
# 인덱스 8028: '정말 너무 힘들어.' → 거리: 10
# 인덱스 8029: '정말 너무 힘듭니다' → 거리: 10
# 인덱스 8030: '정말 너무너무 힘듭니다' → 거리: 12
# 인덱스 8031: '정말 다시돌아 온다면' → 거리: 11
# 인덱스 8032: '정말 뜨겁게 사랑했어.' → 거리: 12
# 인덱스 8033: '정말 막장으로 헤어지신분 계신가??' → 거리: 19
# 인덱스 8034: '정말 모두 잊고 새출발할꺼야' → 거리: 15
# 인덱스 8035: '정말 모든게 그립지만.' → 거리: 12
# 인덱스 8036: '정말 모르겠습니다.' → 거리: 10
# 인덱스 8037: '정말 무슨생각인지 궁금하네' → 거리: 14
# 인덱스 8038: '정말 미안하다 말밖에는' → 거리: 11
# 인덱스 8039: '정말 미쳐버리겠네' → 거리: 9
# 인덱스 8040: '정말 미치겠네' → 거리: 7
# 인덱스 8041: '정말 복합적으로 힘드네' → 거리: 12
# 인덱스 8042: '정말 사람이란' → 거리: 7
# 인덱스 8043: '정말 상처가 잡혀지질않으니 지칩니다' → 거리: 19
# 인덱스 8044: '정말 서로 좋았는데 엊갈림.' → 거리: 15
# 인덱스 8045: '정말 속상하고 답답하고 할 수 있는게 없네' → 거리: 23
# 인덱스 8046: '정말 숨막혀 ㅠㅠ' → 거리: 9
# 인덱스 8047: '정말 슬프고 죽고싶어' → 거리: 11
# 인덱스 8048: '정말 아직 너무 사랑합니다 잡고 싶습니다' → 거리: 22
# 인덱스 8049: '정말 아프고 힘드네' → 거리: 10
# 인덱스 8050: '정말 연애하고싶지않네' → 거리: 11
# 인덱스 8051: '정말 오락가락 언제 괜찮아질지' → 거리: 16
# 인덱스 8052: '정말 오랜만에 글을 쓰네' → 거리: 13
# 인덱스 8053: '정말 왜 이러는걸까' → 거리: 10
# 인덱스 8054: '정말 웃긴건' → 거리: 6
# 인덱스 8055: '정말 이건 너무하다 싶을정도로 힘들어' → 거리: 20
# 인덱스 8056: '정말 이번엔 끝인거겠죠' → 거리: 12
# 인덱스 8057: '정말 이해할수가 없네ㅜ' → 거리: 12
# 인덱스 8058: '정말 잊은걸까?' → 거리: 8
# 인덱스 8059: '정말 잔인하네' → 거리: 7
# 인덱스 8060: '정말 제가 이해가 안갈 정도로 잘못한건가?' → 거리: 22
# 인덱스 8061: '정말 제가 이해안되고 견딜수 없을만큼 아파' → 거리: 22
# 인덱스 8062: '정말 처량하게 혼자' → 거리: 10
# 인덱스 8063: '정말 할게 없네.' → 거리: 9
# 인덱스 8064: '정말 화가 나' → 거리: 7
# 인덱스 8065: '정말 후회없고 미련없이 사랑했던 사람들!!!' → 거리: 24
# 인덱스 8066: '정말 희망 없는 건가?' → 거리: 12
# 인덱스 8067: '정말 힘드네' → 거리: 6
# 인덱스 8068: '정말 힘드네' → 거리: 6
# 인덱스 8069: '정말 힘드네.' → 거리: 7
# 인덱스 8070: '정말 힘드네. 결혼 앞두고 생각할 시간.' → 거리: 22
# 인덱스 8071: '정말 힘들게 헤어졌습니다' → 거리: 13
# 인덱스 8072: '정말 힘들다' → 거리: 6
# 인덱스 8073: '정말 힘듭니다' → 거리: 7
# 인덱스 8074: '정말. 정말 쉽지가 않네. 이럴 땐 어떡해야 할까' → 거리: 27
# 인덱스 8075: '정말.내 자신이 싫다' → 거리: 11
# 인덱스 8076: '정말로 끝났네 이젠' → 거리: 10
# 인덱스 8077: '정말로 사랑한다면' → 거리: 9
# 인덱스 8078: '정말로 이별하려고 준비합니다.' → 거리: 16
# 인덱스 8079: '정말로 헤어졌네' → 거리: 8
# 인덱스 8080: '정말로 헤어졌습니다' → 거리: 10
# 인덱스 8081: '정말이지 이렇게 살고 싶지 않네' → 거리: 17
# 인덱스 8082: '정말잊어보려고 모든수단을 동원했지만.' → 거리: 20
# 인덱스 8083: '정신 차려야 하는데' → 거리: 10
# 인덱스 8084: '정신과 방금다녀와서 처방전 받고 왔어.' → 거리: 21
# 인덱스 8085: '정신과 찾아 왔어' → 거리: 9
# 인덱스 8086: '정신병 걸릴 것 같네' → 거리: 11
# 인덱스 8087: '정신이 없어' → 거리: 6
# 인덱스 8088: '정신차려야 하는거 아는데.' → 거리: 14
# 인덱스 8089: '정신차리자 정신!!' → 거리: 10
# 인덱스 8090: '정은 많지만 설렘이 없다는 이유로 헤어졌습니다.' → 거리: 26
# 인덱스 8091: '제 마음과 머리가 일치가 안되.' → 거리: 16
# 인덱스 8092: '제 아주 오래전 이별' → 거리: 11
# 인덱스 8093: '제 이야기를 풀어보고 싶습니다.' → 거리: 17
# 인덱스 8094: '제 잘못으로 여자친구가 떠났네' → 거리: 16
# 인덱스 8095: '제 잘못입니다' → 거리: 7
# 인덱스 8096: '제 친구가 그러더라구' → 거리: 11
# 인덱스 8097: '제 친구가 술마시면서 잊으려고' → 거리: 16
# 인덱스 8098: '제가 그녀를 놓아줬어.' → 거리: 12
# 인덱스 8099: '제가 그동안 착각 속에 살았습니다' → 거리: 17
# 인덱스 8100: '제가 놓았던 손을 다시 잡으려니 힘드네.' → 거리: 22
# 인덱스 8101: '제가 먼저 파혼 하자고 매달리고 있습니다' → 거리: 22
# 인덱스 8102: '제가 어떻게 행동해야할지 모르겠어' → 거리: 18
# 인덱스 8103: '제가 이상한 건가요?' → 거리: 11
# 인덱스 8104: '제가 잘하고 있는걸까?' → 거리: 12
# 인덱스 8105: '제가 제 복을 찬거겠죠 .' → 거리: 14
# 인덱스 8106: '제가 집착하는 중이에요' → 거리: 12
# 인덱스 8107: '제가나쁜건지 그녀가나쁜건지.' → 거리: 15
# 인덱스 8108: '제가너무집착했어' → 거리: 8
# 인덱스 8109: '제길' → 거리: 2
# 인덱스 8110: '제발 그만 좀 나와주라.' → 거리: 13
# 인덱스 8111: '제발 도와줘' → 거리: 6
# 인덱스 8112: '제발 머리가 나빠졌음 좋겠습니다.' → 거리: 18
# 인덱스 8113: '제발 잠좀 자게해주라' → 거리: 11
# 인덱스 8114: '제발 저좀 살려주세요 힘들어' → 거리: 15
# 인덱스 8115: '제발 힘들면 기대줘' → 거리: 10
# 인덱스 8116: '제일 짜증나는게뭐냐면 문자로 헤어졌다는 거야' → 거리: 24
# 인덱스 8117: '제자리 지키기.' → 거리: 8
# 인덱스 8118: '제잘못으로인한이별' → 거리: 9
# 인덱스 8119: '제정신이 아닌거 같아' → 거리: 11
# 인덱스 8120: '젠장' → 거리: 2
# 인덱스 8121: '조금 아픈가 보다 아주 쪼금' → 거리: 15
# 인덱스 8122: '조금 힘들어.' → 거리: 7
# 인덱스 8123: '조금만 더 참을껄' → 거리: 9
# 인덱스 8124: '조금만 사랑할걸' → 거리: 8
# 인덱스 8125: '조금씩 무뎌져가나봐' → 거리: 10
# 인덱스 8126: '조금씩 아물어가는건가 이별의 상처' → 거리: 18
# 인덱스 8127: '조금의 결심이서네' → 거리: 9
# 인덱스 8128: '조만간 다른 사람 만날꺼 같아' → 거리: 16
# 인덱스 8129: '조바심 나네' → 거리: 6
# 인덱스 8130: '조언 부탁드립니다' → 거리: 9
# 인덱스 8131: '조언 좀 구하겠습니다' → 거리: 11
# 인덱스 8132: '조언 좀 해주세요 ㅠㅠ' → 거리: 12
# 인덱스 8133: '조울증인가봐' → 거리: 6
# 인덱스 8134: '좀 무뎌졌나 했는데' → 거리: 10
# 인덱스 8135: '좀 웃어주지' → 거리: 6
# 인덱스 8136: '좀 짜증나네' → 거리: 6
# 인덱스 8137: '종교 그리고 이별 그리고 재회.' → 거리: 17
# 인덱스 8138: '종교 문제가 해결이 안되네' → 거리: 13
# 인덱스 8139: '좋다가 밉다가 무한반복' → 거리: 12
# 인덱스 8140: '좋아하지만 힘들어서 헤어지자고 먼저 얘기했어' → 거리: 24
# 인덱스 8141: '좋았던 추억까지 잿빛으로 변하고 있네.' → 거리: 21
# 인덱스 8142: '좋은 사람 많아' → 거리: 8
# 인덱스 8143: '좋은 사람으로 남는다는것' → 거리: 13
# 인덱스 8144: '좋은 이별을 하려면 어떻게 해야 할까??' → 거리: 22
# 인덱스 8145: '좋은 하루였어' → 거리: 7
# 인덱스 8146: '좋은꿈 꿨다 생각해' → 거리: 10
# 인덱스 8147: '좋은남자 만나서 행복하게 살아라.' → 거리: 18
# 인덱스 8148: '좋은이별은 어떤건가' → 거리: 10
# 인덱스 8149: '죄송해 너무답답해서 여기에올려봐' → 거리: 17
# 인덱스 8150: '주말은더 힘들어' → 거리: 8
# 인덱스 8151: '주말이 제일 힘드네' → 거리: 10
# 인덱스 8152: '주말이 참 힘들겠어' → 거리: 10
# 인덱스 8153: '주말이네' → 거리: 4
# 인덱스 8154: '주말이라 더 힘들어 견디세 그저 견디는 수밖에 없어 ㅠ' → 거리: 30
# 인덱스 8155: '주변사람들에게 너무 미안합니다.' → 거리: 16
# 인덱스 8156: '주저리 주저리하게 돼' → 거리: 11
# 인덱스 8157: '주저리주저리' → 거리: 6
# 인덱스 8158: '주저리주저리 푸념글' → 거리: 10
# 인덱스 8159: '주차장이 꽉 찼어' → 거리: 9
# 인덱스 8160: '주체가안된다' → 거리: 5
# 인덱스 8161: '주체할수 없는 눈물이 흐르네.' → 거리: 16
# 인덱스 8162: '죽겠다 진짜' → 거리: 6
# 인덱스 8163: '죽고 싶은 심정에 상담을 청합니다.' → 거리: 19
# 인덱스 8164: '죽고싶네' → 거리: 4
# 인덱스 8165: '죽구싶네요' → 거리: 5
# 인덱스 8166: '죽는게 더 편할려나' → 거리: 10
# 인덱스 8167: '죽어가는.' → 거리: 5
# 인덱스 8168: '죽을 것 같아' → 거리: 7
# 인덱스 8169: '죽을거 같네' → 거리: 6
# 인덱스 8170: '죽을거같죠?사람은 간사하네' → 거리: 14
# 인덱스 8171: '죽을것같아' → 거리: 5
# 인덱스 8172: '죽을만큼 보고싶다.' → 거리: 10
# 인덱스 8173: '죽진 못하겠구 겁이나고' → 거리: 12
# 인덱스 8174: '준비중' → 거리: 3
# 인덱스 8175: '준비할 시간을안주네' → 거리: 9
# 인덱스 8176: '중2 히스테리 알아?' → 거리: 11
# 인덱스 8177: '중국어 혼자 공부 가능한가?' → 거리: 15
# 인덱스 8178: '증오' → 거리: 2
# 인덱스 8179: '지겹네' → 거리: 3
# 인덱스 8180: '지겹다' → 거리: 3
# 인덱스 8181: '지금 가장 힘든 거는' → 거리: 11
# 인덱스 8182: '지금 무작정 보러가는중입니다' → 거리: 15
# 인덱스 8183: '지금 비오는데 제일 생각나는 사람' → 거리: 18
# 인덱스 8184: '지금 생각하고 있는건 망상 일뿐입니다' → 거리: 20
# 인덱스 8185: '지금 연락 왔어' → 거리: 8
# 인덱스 8186: '지금 이 순간. 너무 힘들어' → 거리: 15
# 인덱스 8187: '지금 이감정' → 거리: 6
# 인덱스 8188: '지금도 전하지 못하는 한 마디' → 거리: 16
# 인덱스 8189: '지금의 나에겐 없는 너의 일상' → 거리: 16
# 인덱스 8190: '지금이 겨울이라 참 다행이이네' → 거리: 16
# 인덱스 8191: '지긋지긋한 연휴.' → 거리: 9
# 인덱스 8192: '지나가는 말이 가슴을 후벼파' → 거리: 15
# 인덱스 8193: '지나간다.' → 거리: 5
# 인덱스 8194: '지나고나면 .' → 거리: 7
# 인덱스 8195: '지난 갑작스러운 이별통보' → 거리: 13
# 인덱스 8196: '지난 주말부터 또 후유증이' → 거리: 14
# 인덱스 8197: '지난주 이별했네' → 거리: 8
# 인덱스 8198: '지독하고 질긴 인연을 끝내려고 해' → 거리: 18
# 인덱스 8199: '지루함에 지쳤다네.' → 거리: 10
# 인덱스 8200: '지옥같은 5월이 다가 오네ㅜㅜ' → 거리: 16
# 인덱스 8201: '지옥같은 주말.' → 거리: 8
# 인덱스 8202: '지워지지 않습니다.' → 거리: 10
# 인덱스 8203: '지쳐서 헤어지자고 한 남자도 후폭풍올까?' → 거리: 22
# 인덱스 8204: '지쳐서 헤어진 남자랑은 재회가능성' → 거리: 18
# 인덱스 8205: '지치네' → 거리: 3
# 인덱스 8206: '지친다' → 거리: 3
# 인덱스 8207: '지하철만 타면 생각나' → 거리: 11
# 인덱스 8208: '직장과 이별' → 거리: 6
# 인덱스 8209: '진실을 알면서도 왜 확인하려는걸까?' → 거리: 19
# 인덱스 8210: '진정 헤어진 여친 맘은 못 돌리는 건가?' → 거리: 22
# 인덱스 8211: '진짜 끝' → 거리: 4
# 인덱스 8212: '진짜 끝이었다는걸아는데도' → 거리: 13
# 인덱스 8213: '진짜 마지막까지 믿었습니다.' → 거리: 15
# 인덱스 8214: '진짜 미치겠다' → 거리: 7
# 인덱스 8215: '진짜 사랑해서 아픈 느낌.' → 거리: 14
# 인덱스 8216: '진짜 시간이 약인지' → 거리: 10
# 인덱스 8217: '진짜 어의 없네.ㅠㅠ' → 거리: 11
# 인덱스 8218: '진짜 어이없고 화 나내' → 거리: 12
# 인덱스 8219: '진짜 이건 뭐.' → 거리: 8
# 인덱스 8220: '진짜 이별' → 거리: 5
# 인덱스 8221: '진짜 이제 안녕' → 거리: 6
# 인덱스 8222: '진짜 이해가 안가 근데 잊을려고' → 거리: 16
# 인덱스 8223: '진짜 인간적으로 카톡으로 이별통보' → 거리: 18
# 인덱스 8224: '진짜 잊혀질까?' → 거리: 8
# 인덱스 8225: '진짜 잠 좀 자고 싶네' → 거리: 12
# 인덱스 8226: '진짜 정신병 걸릴꺼 같은데' → 거리: 14
# 인덱스 8227: '진짜 하루하루 너무 마음 찢어지고 숨 못쉬겠어' → 거리: 25
# 인덱스 8228: '진짜끝이보이네' → 거리: 7
# 인덱스 8229: '진짜미칠꺼같네' → 거리: 7
# 인덱스 8230: '진짜헤어졌네 결국' → 거리: 9
# 인덱스 8231: '질긴 사랑과 아픔의 정도' → 거리: 13
# 인덱스 8232: '질긴 인연 드디어 끝인 것 같네' → 거리: 17
# 인덱스 8233: '질린다네.' → 거리: 5
# 인덱스 8234: '질질 끄는연애 드디어끝이네.' → 거리: 15
# 인덱스 8235: '집에 들어가기가 무서워' → 거리: 12
# 인덱스 8236: '집에서 웃고 떠들고 있지만' → 거리: 14
# 인덱스 8237: '집착? 미련? 사랑?' → 거리: 11
# 인덱스 8238: '집착같아' → 거리: 4
# ...
# 인덱스 11445: '짝남한테 고백했는데 잘 됐으면 좋겠다.' → 거리: 21
# 인덱스 11446: '짝남한테 괜히 만나자고 했나봐.' → 거리: 17
# 인덱스 11447: '짝남한테 내일 영화보자고 말해도 될까?' → 거리: 21
# 인덱스 11448: '짝남한테 늦은 생일 선물 주러 가는데 떨려.' → 거리: 24
# 인덱스 11449: '짝남한테 라인 왔는데 답장 뭐라고 해야할지 모르겠어.' → 거리: 29
# 인덱스 11450: '짝남한테 문자 왔어.' → 거리: 11
# 인덱스 11451: '짝남한테 밤늦게 나오라고 했더리 진짜 나왔줬는데 저한테 호감이 있는 걸까요?' → 거리: 42
# 인덱스 11452: '짝남한테 밥 먹자고 그냥 해볼까.' → 거리: 18
# 인덱스 11453: '짝남한테 시덥지 않은 걸로 선톡해도 될까?' → 거리: 23
# 인덱스 11454: '짝남한테 실망했어요.' → 거리: 11
# 인덱스 11455: '짝남한테 아침에 데이트 신청했는데 오늘 야근이야.' → 거리: 27
# 인덱스 11456: '짝남한테 여러 번 차이다가 나중에 사귀게 된 사람도 있을까?' → 거리: 33
# 인덱스 11457: '짝남한테 연락할까?' → 거리: 10
# 인덱스 11458: '짝남한테 은근슬쩍 좋아하는 티 내는 방법 좀.' → 거리: 25
# 인덱스 11459: '짝남한테 잘 보이고 싶은데.' → 거리: 15
# 인덱스 11460: '짝남한테 정 떼는 방법 없나.' → 거리: 16
# 인덱스 11461: '짝남한테 좋아하는거 들켰는데 그냥 예전처럼 편하게 지내고 싶어.' → 거리: 35
# 인덱스 11462: '짝남한테 주말에 만나자고 했는데 일 있대 계속 언제 되는지 물어봐도 되나.' → 거리: 41
# 인덱스 11463: '짝남한테 크리스마스 선물할건데 추천 좀.' → 거리: 22
# 인덱스 11464: '짝남한테 톡 와 있네.' → 거리: 12
# 인덱스 11465: '짝남한테 혼자 화나고.' → 거리: 12
# 인덱스 11466: '짝남한테도 철벽이게 돼 왜그럴까.' → 거리: 18
# 인덱스 11467: '짝녀 고민 들어줘.' → 거리: 10
# 인덱스 11468: '짝녀 관련돼서 악몽을 자주 꾸는데 불안함.' → 거리: 22
# 인덱스 11469: '짝녀 기분이 안좋아 보여서 신경 쓰임.' → 거리: 20
# 인덱스 11470: '짝녀 나한테 마음이 있는걸까?' → 거리: 16
# 인덱스 11471: '짝녀 남친 생겼네.' → 거리: 10
# 인덱스 11472: '짝녀 때문에 화가나요.' → 거리: 12
# 인덱스 11473: '짝녀 마음 정리하는 중이데 자꾸 꿈에 나옵니다.' → 거리: 26
# 인덱스 11474: '짝녀 보고 싶다.' → 거리: 9
# 인덱스 11475: '짝녀 보란 듯이 성공하고 싶습니다.' → 거리: 19
# 인덱스 11476: '짝녀 보란 듯이 잊고 싶어요.' → 거리: 16
# 인덱스 11477: '짝녀 생각에 잠을 못자겠어.' → 거리: 15
# 인덱스 11478: '짝녀 생각할수록 정리 되는 느낌.' → 거리: 18
# 인덱스 11479: '짝녀 선물 어디까지 가능?' → 거리: 14
# 인덱스 11480: '짝녀 알바 그만둬서 못나는데 연락처 물어보면 싫어할까.' → 거리: 30
# 인덱스 11481: '짝녀 연락 끊긴지 꽤 됐는데 연락해도 될까요?' → 거리: 25
# 인덱스 11482: '짝녀 오랫동안 멀리서 지켜보기만 하고 있습니다.' → 거리: 25
# 인덱스 11483: '짝녀 있는데 소개팅 들어오면 받아도 되나요?' → 거리: 24
# 인덱스 11484: '짝녀 잊으려면 인스타부터 안 해야할듯.' → 거리: 20
# 인덱스 11485: '짝녀 줄 센스있는 선물 추천 좀 해주세요.' → 거리: 23
# 인덱스 11486: '짝녀 프사 자음이 궁금함.' → 거리: 14
# 인덱스 11487: '짝녀가 고시생인데 언제까지 기다려야 할까요.' → 거리: 24
# 인덱스 11488: '짝녀가 공시생인데 기다릴까요?' → 거리: 16
# 인덱스 11489: '짝녀가 나를 떠보는 걸까.' → 거리: 14
# 인덱스 11490: '짝녀가 나를 좋아하는 애의 절친이야.' → 거리: 20
# 인덱스 11491: '짝녀가 나한테 관심이 전혀 없는 듯.' → 거리: 20
# 인덱스 11492: '짝녀가 나한테 먼저 연락올 일은 없겠지?' → 거리: 22
# 인덱스 11493: '짝녀가 날 너무 친구로 생각해.' → 거리: 17
# 인덱스 11494: '짝녀가 내 친구를 좋아하는 것 같음. 어떡해?' → 거리: 25
# 인덱스 11495: '짝녀가 내 친구를 좋아해.' → 거리: 14
# 인덱스 11496: '짝녀가 내 톡은 안 읽고 프사 바꿈.' → 거리: 19
# 인덱스 11497: '짝녀가 내가 좋아하는 걸 알아버렸어.' → 거리: 20
# 인덱스 11498: '짝녀가 너무 이뻐서 찝적대는 사람이 너무 많아.' → 거리: 26
# 인덱스 11499: '짝녀가 다른 남자를 좋아한대.' → 거리: 16
# 인덱스 11500: '짝녀가 다른반인데 친해지는 방법없을까?' → 거리: 21
# 인덱스 11501: '짝녀가 단톡에선 답장하고 갠톡은 답장 안해.' → 거리: 23
# 인덱스 11502: '짝녀가 몇일째 카톡 안읽씹하면 거절인거죠?' → 거리: 22
# 인덱스 11503: '짝녀가 사귀던 사람이랑 헤어졌는데 좋아한다고 고백해도 되나.' → 거리: 33
# 인덱스 11504: '짝녀가 어떻게 하면 내 생각을 하게 할까?' → 거리: 23
# 인덱스 11505: '짝녀가 여친이 되었습니다.' → 거리: 14
# 인덱스 11506: '짝녀가 연락 안 되고 있는데 자나?' → 거리: 18
# 인덱스 11507: '짝녀가 예쁜 건 아닌데 끌려.' → 거리: 16
# 인덱스 11508: '짝녀가 외국인인데 연락처 물어봐도 될까.' → 거리: 22
# 인덱스 11509: '짝녀가 외국인인데 좋아해도 되나?' → 거리: 18
# 인덱스 11510: '짝녀가 우리 과에서 인기가 너무 많아.' → 거리: 21
# 인덱스 11511: '짝녀가 우리 과에서 제일 인기가 많은 듯.' → 거리: 23
# 인덱스 11512: '짝녀가 운동을 한다는데 같이 하고싶어' → 거리: 20
# 인덱스 11513: '짝녀가 음식을 가리는 편인데 뭘 먹으면 좋을까?' → 거리: 26
# 인덱스 11514: '짝녀가 이사간다는데 너무 힘들어.' → 거리: 18
# 인덱스 11515: '짝녀가 있는데 내게 연애는 사치인거 같아.' → 거리: 23
# 인덱스 11516: '짝녀가 있었는데 못 잊겠어.' → 거리: 15
# 인덱스 11517: '짝녀가 저한테 관심이 없는 것 같은데도 계속 연락해도 될까요.' → 거리: 34
# 인덱스 11518: '짝녀가 절 신경쓰는 것 같은 건 내 착가인가요?' → 거리: 26
# 인덱스 11519: '짝녀가 졸업하는데 어떤 꽃을 선물하면 좋아할까?' → 거리: 26
# 인덱스 11520: '짝녀가 좋아하는 사람 있거나 남친 있으면 포기하는 이유가 뭐임?' → 거리: 35
# 인덱스 11521: '짝녀가 좋아하는 사람이 있답니다.' → 거리: 18
# 인덱스 11522: '짝녀가 좋아하는거 눈치 1도 못챔.' → 거리: 19
# 인덱스 11523: '짝녀가 차갑게 굴면 어떻게 해요?' → 거리: 18
# 인덱스 11524: '짝녀가 학교에서 소문이 안 좋아.' → 거리: 17
# 인덱스 11525: '짝녀는 짝녀일 뿐이건가.' → 거리: 13
# 인덱스 11526: '짝녀랑 갑자기 어색해졌습니다.' → 거리: 16
# 인덱스 11527: '짝녀랑 누나 이름이 똑같애.' → 거리: 15
# 인덱스 11528: '짝녀랑 드디어 사귄다!' → 거리: 12
# 인덱스 11529: '짝녀랑 술 마셨는데 이제 진짜 접어야하나봐.' → 거리: 24
# 인덱스 11530: '짝녀랑 약속 파토 났어요.' → 거리: 14
# 인덱스 11531: '짝녀랑 얼굴 마주보고 대화할 때 미칠 것 같아.' → 거리: 26
# 인덱스 11532: '짝녀랑 연락이 끊겼는데 더 연락하고 싶어.' → 거리: 23
# 인덱스 11533: '짝녀랑 저녁에 보기로 했는데 연락두절임.' → 거리: 22
# 인덱스 11534: '짝녀랑 조금이라도 닮으면 눈이 가는 듯.' → 거리: 22
# 인덱스 11535: '짝녀랑 카톡했던거 다시 읽어 보는데 거의 다만 물어보네.' → 거리: 31
# 인덱스 11536: '짝녀를 반 애들 다 알게 공개적으로 좋아하면 싫어할까요?' → 거리: 31
# 인덱스 11537: '짝녀에게 남친이 있었습니다.' → 거리: 15
# 인덱스 11538: '짝녀에게 내 옷좀 봐달라고 만나자 해도 될까?' → 거리: 25
# 인덱스 11539: '짝녀에게 다가가려면 짝녀의 친구에게 먼저 다가가는게 나을까?' → 거리: 33
# 인덱스 11540: '짝녀와 같이 드라이브갈껀데 어디로 갈까?' → 거리: 22
# 인덱스 11541: '짝녀와 자연스럽게 친해질 수 있는 방법 좀.' → 거리: 24
# 인덱스 11542: '짝녀의 전 남친이 나탔났음.' → 거리: 15
# 인덱스 11543: '짝녀한테 같이 스터디하자고 해도 되나요?' → 거리: 22
# 인덱스 11544: '짝녀한테 고백했는데 미안하대.' → 거리: 15
# 인덱스 11545: '짝녀한테 고백했는데 잘 됐으면.' → 거리: 17
# 인덱스 11546: '짝녀한테 고백했는데 짝녀가 오해하게 해서 너무 미안하다네요.' → 거리: 32
# 인덱스 11547: '짝녀한테 공부 가르쳐달라고 해볼까' → 거리: 18
# 인덱스 11548: '짝녀한테 라인 왔는데 뭐라고 답장 해야할지 모르겠어.' → 거리: 29
# 인덱스 11549: '짝녀한테 문자 왔어.' → 거리: 11
# 인덱스 11550: '짝녀한테 실망했음.' → 거리: 10
# 인덱스 11551: '짝녀한테 여러 번 차였는데 사귈 수 있을까요.' → 거리: 25
# 인덱스 11552: '짝녀한테 연락해볼까?' → 거리: 11
# 인덱스 11553: '짝녀한테 영화 보자고 그냥 해볼까.' → 거리: 19
# 인덱스 11554: '짝녀한테 의미 없는 선톡 해도 될까요?' → 거리: 21
# 인덱스 11555: '짝녀한테 잘 보이고 싶은데.' → 거리: 15
# 인덱스 11556: '짝녀한테 주말에 보자고 연락했는데 일정이 있대요. 언제되는지 계속 물어도 될까요.' → 거리: 45
# 인덱스 11557: '짝녀한테 줄임말 쓰면 안됨?' → 거리: 14
# 인덱스 11558: '짝녀한테 카페 가서 같이 공부하자고 해볼까?' → 거리: 24
# 인덱스 11559: '짝녀한테 크리스마스 선물로 뭐가 좋음?' → 거리: 21
# 인덱스 11560: '짝녀한테 휘둘리고 싶지 않은데 이러는 내가 싫다.' → 거리: 27
# 인덱스 11561: '짝녀한테도 철벽쳐요. 성격이 왜 그럴까요.' → 거리: 23
# 인덱스 11562: '짝사랑 그만하고 싶다' → 거리: 11
# 인덱스 11563: '짝사랑 그만할래' → 거리: 8
# 인덱스 11564: '짝사랑 끝내고 나니 마음이 공허하다.' → 거리: 20
# 인덱스 11565: '짝사랑 시작하고 감정 기복이 심해.' → 거리: 19
# 인덱스 11566: '짝사랑 중이었는데 솔로 탈출했어요.' → 거리: 19
# 인덱스 11567: '짝사랑 중인 내가 이해가 안돼.' → 거리: 16
# 인덱스 11568: '짝사랑 중인데 나혼자 드라마 찍음.' → 거리: 19
# 인덱스 11569: '짝사랑 중인데 나혼자 영화찍어.' → 거리: 17
# 인덱스 11570: '짝사랑 중인데 나혼자 치정 로맨스야.' → 거리: 20
# 인덱스 11571: '짝사랑 중인데 이 세상에 나만 힘든 것 같아.' → 거리: 25
# 인덱스 11572: '짝사랑 중일 때 장점.' → 거리: 12
# 인덱스 11573: '짝사랑 진짜 못해먹겠다.' → 거리: 13
# 인덱스 11574: '짝사랑 포기하는 것도 힘드네.' → 거리: 16
# 인덱스 11575: '짝사랑 포기하려니까 우울해.' → 거리: 15
# 인덱스 11576: '짝사랑 하는 남자 때문에 하루에도 몇 번 기분이 달라져.' → 거리: 31
# 인덱스 11577: '짝사랑 하는 남자가 외국인인데 어떻게 다가갈 수 있을까?' → 거리: 31
# 인덱스 11578: '짝사랑 하는 남자애가 이사 간대.' → 거리: 18
# 인덱스 11579: '짝사랑 하는 사람과 친해질 수 있는 방법 조언 좀.' → 거리: 28
# 인덱스 11580: '짝사랑 하는 사람보다 좋은 사람 만날거야.' → 거리: 23
# 인덱스 11581: '짝사랑 하는 사람을 보냈습니다. 위로해 주세요.' → 거리: 26
# 인덱스 11582: '짝사랑 하는 사람이 날 좋아할 확률은?' → 거리: 21
# 인덱스 11583: '짝사랑 하는 사람이 날 좋아할리는 없겠지?' → 거리: 23
# 인덱스 11584: '짝사랑 하는 사람이 너무 잘나서 내가 작아보여.' → 거리: 26
# 인덱스 11585: '짝사랑 하는 사람이랑 잘됐으면 좋겠다.' → 거리: 21
# 인덱스 11586: '짝사랑 하는 상대가 나를 싫어하는 것 같애.' → 거리: 24
# 인덱스 11587: '짝사랑 하는 여자 때문에 신경이 곤두서.' → 거리: 22
# 인덱스 11588: '짝사랑 하는 여자가 헷갈리게 합니다.' → 거리: 20
# 인덱스 11589: '짝사랑 하는 여자랑 뽀뽀하는 꿈 꿨어요.' → 거리: 22
# 인덱스 11590: '짝사랑 하는 여자애가 오늘 꿈에 나온다면 소원이 없겠네.' → 거리: 31
# 인덱스 11591: '짝사랑 하는 여자에 대한 고민 좀 들어주세요.' → 거리: 25
# 인덱스 11592: '짝사랑 하는 여자한테 고백한다? 안한다?' → 거리: 21
# 인덱스 11593: '짝사랑 하니까 감정 기복 장난 아님.' → 거리: 20
# 인덱스 11594: '짝사랑 하던 사람 못 잊을 것 같애.' → 거리: 20
# 인덱스 11595: '짝사랑 하던 사람이 있는데 끝까지 포기 못할 것 같아.' → 거리: 30
# 인덱스 11596: '짝사랑 하던 사람이랑 썸 타고 싶어.' → 거리: 20
# 인덱스 11597: '짝사랑 하던 사람이랑 썸 탈 것 같애.' → 거리: 21
# 인덱스 11598: '짝사랑 하던 사람한테 고백했는데 차임. 계속 좋아해도 될까.' → 거리: 33
# 인덱스 11599: '짝사랑 하면 무슨 기분인지 알긴 해요?' → 거리: 21
# 인덱스 11600: '짝사랑 하면서 내가 초라하게 느껴져.' → 거리: 20
# 인덱스 11601: '짝사랑 해봤어?' → 거리: 8
# 인덱스 11602: '짝사랑 했던 그가 떠나갔어.' → 거리: 15
# 인덱스 11603: '짝사랑 했던 그녀가 남친이 생겼대.' → 거리: 19
# 인덱스 11604: '짝사랑 했던 그에게 여자친구가 생겼어.' → 거리: 21
# 인덱스 11605: '짝사랑 했던 여자가 떠나갔네.' → 거리: 16
# 인덱스 11606: '짝사랑 힘들어' → 거리: 7
# 인덱스 11607: '짝사랑만 하다보니 이 세상에 나 혼자인 것 같네.' → 거리: 27
# 인덱스 11608: '짝사랑만 하다보니 자존감이 떨어졌어.' → 거리: 20
# 인덱스 11609: '짝사랑만이 답일까.' → 거리: 10
# 인덱스 11610: '짝사랑에서 연인으로 발전 가능?' → 거리: 17
# 인덱스 11611: '짝사랑에서 연인으로 발전하려면 어떻게 해야 해?' → 거리: 26
# 인덱스 11612: '짝사랑은 안 이뤄지나봐.' → 거리: 12
# 인덱스 11613: '짝사랑은 언제까지나 짝사랑일 뿐이가봐요.' → 거리: 22
# 인덱스 11614: '짝사랑은 언제나 고독할까.' → 거리: 14
# 인덱스 11615: '짝사랑은 짝사랑으로 남는게 좋은 걸까요.' → 거리: 22
# 인덱스 11616: '짝사랑은 힘든 거 같아' → 거리: 12
# 인덱스 11617: '짝사랑을 끝내니까 마음이 허전해.' → 거리: 18
# 인덱스 11618: '짝사랑을 너무 오래해서 현타 와.' → 거리: 18
# 인덱스 11619: '짝사랑을 하다보니 자존감이 낮아졌어.' → 거리: 20
# 인덱스 11620: '짝사랑이 이렇게 힘들줄을 몰랐어요.' → 거리: 19
# 인덱스 11621: '짝사랑이 이뤄지지 않을 것 같은데 계속 좋아해도 될까?' → 거리: 30
# 인덱스 11622: '짝사랑인 상대한테 고백했는데 짝남이 오해하게 해서 미안하대.' → 거리: 32
# 인덱스 11623: '짝사랑인가 썸인가' → 거리: 9
# 인덱스 11624: '짝사랑인지 썸인지 구별하는 법' → 거리: 16
# 인덱스 11625: '짝사랑중이야' → 거리: 6
# 인덱스 11626: '짝사랑중인데 그 애는 저를 잘 알지 못하는데 연락을 하면 놀랠까요?' → 거리: 37
# 인덱스 11627: '짝사랑하는 기분이 뭔지 알아요?' → 거리: 17
# 인덱스 11628: '짝사랑하는 남자는 내가 싫은가봐.' → 거리: 18
# 인덱스 11629: '짝사랑하는 사람에 대한 마음이 갑자기 식었어.' → 거리: 25
# 인덱스 11630: '짝사랑하는 사람이랑 엄청 편하게 지내는데 썸 가능?' → 거리: 28
# 인덱스 11631: '짝사랑하는 여자가 저를 싫어하나봅니다.' → 거리: 21
# 인덱스 11632: '짝사랑하다고 솔탈함. 기 받아가.' → 거리: 18
# 인덱스 11633: '짝사랑하면 어떤 기분이야?' → 거리: 14
# 인덱스 11634: '짝사랑한 만큼 상처도 깊어져.' → 거리: 16
# 인덱스 11635: '쪼금 지겨워진 거 같아' → 거리: 12
# 인덱스 11636: '차 없으면 데이트 못해?' → 거리: 13
# 인덱스 11637: '차로 데려다줬는데' → 거리: 9
# 인덱스 11638: '차였는데 좋아하는 감정이 사라지질 않아요.' → 거리: 23
# 인덱스 11639: '착각이면 어떡해' → 거리: 8
# 인덱스 11640: '착각일 수도 있는데 서로 좋아하는 것 같으면 고백해?' → 거리: 29
# 인덱스 11641: '착해서 잘해주는 건지 좋아하는 건지' → 거리: 19
# 인덱스 11642: '착해서 잘해주는 건지 좋아하는 건지' → 거리: 19
# 인덱스 11643: '참 많이 좋아했는데.' → 거리: 11
# 인덱스 11644: '처음 마음이 아픈게 첫사랑인가' → 거리: 16
# 인덱스 11645: '처음 커플템으로 어떤거를 할까?' → 거리: 17
# 인덱스 11646: '처음에는 가벼운 마음이었는데' → 거리: 15
# 인덱스 11647: '천년의 짝사랑이 식는 기분.' → 거리: 15
# 인덱스 11648: '첫 눈에 반하는게 가능해?' → 거리: 14
# 인덱스 11649: '첫 눈에 반하는게 가능해?' → 거리: 14
# 인덱스 11650: '첫 데이트에 뭐 먹는걸 좋을까?' → 거리: 17
# 인덱스 11651: '첫 만남에 키스했는데 너무 빠른걸까?' → 거리: 20
# 인덱스 11652: '첫눈에 반함' → 거리: 6
# 인덱스 11653: '첫눈에 반해서 좋아할 수 있어?' → 거리: 17
# 인덱스 11654: '첫데이트 어디로 가는게 좋을까?' → 거리: 17
# 인덱스 11655: '첫사랑 다시 만나도 사랑할 수 있을까?' → 거리: 21
# 인덱스 11656: '첫사랑 보고 싶어' → 거리: 9
# 인덱스 11657: '첫사랑 생각나' → 거리: 7
# 인덱스 11658: '첫사랑 생각나' → 거리: 7
# 인덱스 11659: '첫사랑 생각만해도 아련해' → 거리: 13
# 인덱스 11660: '첫사랑도 내 생각할까?' → 거리: 12
# 인덱스 11661: '첫사랑도 내가 보고 싶을까?' → 거리: 15
# 인덱스 11662: '첫사랑을 다시 만났어.' → 거리: 12
# 인덱스 11663: '첫사랑을 추억해' → 거리: 8
# 인덱스 11664: '첫사랑이 떠올라' → 거리: 8
# 인덱스 11665: '첫사랑인 거 같아' → 거리: 9
# 인덱스 11666: '청첩장 고르고 있어' → 거리: 10
# 인덱스 11667: '청첩장 골랐어' → 거리: 7
# 인덱스 11668: '청첩장 누구 주지?' → 거리: 10
# 인덱스 11669: '청첩장 누구한테 주지?' → 거리: 12
# 인덱스 11670: '청첩장 누구한테 줘야할지' → 거리: 13
# 인덱스 11671: '청첩장 돌리기 귀찮아' → 거리: 11
# 인덱스 11672: '청첩장 만들어야지' → 거리: 9
# 인덱스 11673: '청첩장을 찍는 날이 오다니' → 거리: 14
# 인덱스 11674: '최근에 헤어진 짝남한테 연락하면 주변에서 욕할까?' → 거리: 27
# 인덱스 11675: '최근에 헤어진 짝남한테 지금 연락하기는 너무 이를까?' → 거리: 29
# 인덱스 11676: '최근에 헤어진 짝녀한테 연락하면 내 연락을 받아줄까?' → 거리: 29
# 인덱스 11677: '최소 썸인 듯.' → 거리: 8
# 인덱스 11678: '최악의 소개팅이었어' → 거리: 10
# 인덱스 11679: '출산휴가 있는 회사로 이직할까?' → 거리: 17
# 인덱스 11680: '취업준비하는데 연애해도 될까?' → 거리: 16
# 인덱스 11681: '취준생인데 연애 부담 돼.' → 거리: 14
# 인덱스 11682: '취준생인데 연애 해도 될까?' → 거리: 15
# 인덱스 11683: '취향 알고 싶다' → 거리: 8
# 인덱스 11684: '취향 좀 존중해줬으면' → 거리: 11
# 인덱스 11685: '친구 결혼 준비하는 거 보니까 나도 하고 싶어진다' → 거리: 27
# 인덱스 11686: '친구 결혼식에서 축가 준비 중' → 거리: 16
# 인덱스 11687: '친구 사이로도 못 지낼 것 같아.' → 거리: 18
# 인덱스 11688: '친구 짝남이 나 좋아하는데 어떡함.' → 거리: 19
# 인덱스 11689: '친구 짝녀가 날 좋아하는데 어쩔.' → 거리: 18
# 인덱스 11690: '친구가 결혼식 사회 봐주기로 했어' → 거리: 18
# 인덱스 11691: '친구같은 연애 하고 싶어' → 거리: 13
# 인덱스 11692: '친구도 아니고 사귀는 사이도 아닌데 뭐지?' → 거리: 23
# 인덱스 11693: '친구들과의 모임이 너무 많은 사람' → 거리: 18
# 인덱스 11694: '친구들이 브라이덜샤워해준대' → 거리: 14
# 인덱스 11695: '친구들이 사랑하니까 예뻐졌대' → 거리: 15
# 인덱스 11696: '친구들이 짝남 별로라고 하는게 짜증나.' → 거리: 21
# 인덱스 11697: '친구들이 짝녀를 별로라고 하네요.' → 거리: 18
# 인덱스 11698: '친구들하고 욕하고 있는데 짝녀가 들었어.' → 거리: 22
# 인덱스 11699: '친구라도 될 걸 그랬나봐요.' → 거리: 15
# 인덱스 11700: '친구랑 나랑 좋아하는 애가 같으면 어떡해?' → 거리: 23
# 인덱스 11701: '친구랑 사랑하는 사람이 같아' → 거리: 15
# 인덱스 11702: '친구로 남는게 좋을까 그냥 고백할까?' → 거리: 20
# 인덱스 11703: '친구로 좋아하는 건지 이성으로 좋아하는 건지 모르겠어요.' → 거리: 31
# 인덱스 11704: '친구에서 연인이 되려면' → 거리: 12
# 인덱스 11705: '친구의 구남친을 좋아하게 됐어요.' → 거리: 18
# 인덱스 11706: '친구의 남자친구가 눈에 들어와' → 거리: 16
# 인덱스 11707: '친구의 남친 좋아하게 된 거 같아' → 거리: 18
# 인덱스 11708: '친구의 전 여친을 좋아하는 나.' → 거리: 17
# 인덱스 11709: '친구의 전여자친구가 좋은데 사겨도될까?' → 거리: 21
# 인덱스 11710: '친구의 친구를 사랑하는 거 같아' → 거리: 17
# 인덱스 11711: '친구의 친구를 사랑했네' → 거리: 12
# 인덱스 11712: '친구인데 고백해도 될까?' → 거리: 13
# 인덱스 11713: '친구인데 썸 타는 것 같아.' → 거리: 15
# 인덱스 11714: '친한 동생인데 짝남이 되고 있는 느낌이에요.' → 거리: 24
# 인덱스 11715: '친한 동생인데 짝녀가 된 것 같아요.' → 거리: 20
# 인덱스 11716: '친한 동생인데 짝사랑하는 것 같습니다.' → 거리: 21
# 인덱스 11717: '친한 친구가 저를 좋아하는 것 같아요.' → 거리: 21
# 인덱스 11718: '친한 친구의 구남친이랑 사귀어도 될까요?' → 거리: 22
# 인덱스 11719: '친한 친구의 구여친이랑 사귀어도 되나.' → 거리: 21
# 인덱스 11720: '카리스마 있는 사람이 좋아' → 거리: 14
# 인덱스 11721: '카톡 상메에 아직도 누구 좋아한다는 티 내는 법 좀.' → 거리: 29
# 인덱스 11722: '카톡하고 싶고 자꾸 생각나고 그러면 좋아하는 건가?' → 거리: 28
# 인덱스 11723: '카톡하는데 자꾸 웃음 나.' → 거리: 14
# 인덱스 11724: '카톡할때 너무 칼답하면 부담스러워할까?' → 거리: 21
# 인덱스 11725: '카페 알바생이 좋아졌는데 들이대도 괜찮을까?' → 거리: 24
# 인덱스 11726: '카페에서 같이 알바하는 사람이 좋아졌어요.' → 거리: 23
# 인덱스 11727: '커뮤니티 하는 썸남 어때?' → 거리: 14
# 인덱스 11728: '커뮤니티 하는 썸녀 어때?' → 거리: 14
# 인덱스 11729: '커플 여행 가면 잘 싸워?' → 거리: 14
# 인덱스 11730: '커플여행 어떻게 생각해?' → 거리: 13
# 인덱스 11731: '커플여행이 나을까 그냥 우리끼리 갈까?' → 거리: 21
# 인덱스 11732: '커플여행이 나을까 그냥 우리끼리 갈까?' → 거리: 21
# 인덱스 11733: '콩깍지 언제 벗겨져?' → 거리: 11
# 인덱스 11734: '콩깍지 왜 안 벗겨지지?' → 거리: 12
# 인덱스 11735: '콩깍지가 씌었나봐. 아직도 좋아해.' → 거리: 19
# 인덱스 11736: '크리스마스인데 만나자고 해도 됨?' → 거리: 18
# 인덱스 11737: '큰 시험 앞두고 짝사랑 하는 사랑이 생겼어요.' → 거리: 25
# 인덱스 11738: '클럽 좋아하는 남자는 좋아하면 안되겠지.' → 거리: 21
# 인덱스 11739: '클럽에서 만나서 사귀는거 어떻게 생각해?' → 거리: 22
# 인덱스 11740: '클럽에서 만난 남자친구와 오래 갈 수 있을까?' → 거리: 25
# 인덱스 11741: '클럽에서 여자친구 찾아볼까?' → 거리: 15
# 인덱스 11742: '키 작은 남자 좋아하는 여자 있나요?' → 거리: 20
# 인덱스 11743: '키 작은 여자 좋아하는 남자 있나요?' → 거리: 20
# 인덱스 11744: '키 큰 남자 만나고 싶어' → 거리: 13
# 인덱스 11745: '키 큰 여자는 별로인가?' → 거리: 13
# 인덱스 11746: '턱시도 잘 어울림!' → 거리: 10
# 인덱스 11747: '팀장님을 좋아하게 됐는데 고백하면 안되겠지.' → 거리: 23
# 인덱스 11748: '팔베개하고 자다가 팔 저린데 말해야겠지?' → 거리: 22
# 인덱스 11749: '패턴 궁금해' → 거리: 6
# 인덱스 11750: '패턴 아는데 풀어봐도 될까?' → 거리: 15
# 인덱스 11751: '편해지는게 당연한데 속상해.' → 거리: 15
# 인덱스 11752: '풋풋한 사랑 하고 싶어.' → 거리: 13
# 인덱스 11753: '프로포즈 곧 받을 거 같은데' → 거리: 15
# 인덱스 11754: '프로포즈 받았어' → 거리: 8
# 인덱스 11755: '프로포즈할때 영상편지도 주려고' → 거리: 16
# 인덱스 11756: '플라토닉 연애 어때?' → 거리: 11
# 인덱스 11757: '하고 많은 사람 중에 왜 나야?' → 거리: 17
# 인덱스 11758: '하루 종일 같이 있고 싶어' → 거리: 14
# 인덱스 11759: '하루 종일 붙어 있고 싶어' → 거리: 14
# 인덱스 11760: '하루 종일 연락하면 썸?' → 거리: 13
# 인덱스 11761: '하루종일 썸남 생각만 해. 괜찮을까?' → 거리: 20
# 인덱스 11762: '하우스푸어될듯' → 거리: 7
# 인덱스 11763: '학교 짝이랑 썸 타는데' → 거리: 12
# 인덱스 11764: '학교샘 좋아하는 사람 있나?' → 거리: 15
# 인덱스 11765: '학교에 심남 있는데 연락해볼까?' → 거리: 17
# 인덱스 11766: '학교에 좋아하는 여자애의 관심을 어떻게 끌지?' → 거리: 25
# 인덱스 11767: '학교에 좋아하는 오빠한테 어떻게 다가갈까?' → 거리: 23
# 인덱스 11768: '학생일 때 썸 괜찮을까' → 거리: 12
# 인덱스 11769: '학원 다른반에 좋아하는 사람이 있는데 번호를 알고 싶은데 방법 좀 알려주세요.' → 거리: 43
# 인덱스 11770: '학원 선생님을 좋아하는데 티내면 안되겠지.' → 거리: 22
# 인덱스 11771: '학원에 좋아하는 남자애가 생겼어요.' → 거리: 19
# 인덱스 11772: '학원에 좋아하는 여자애가 있는데 말 거는 방법 좀.' → 거리: 28
# 인덱스 11773: '한 눈에 반했어. 그녀한테 좋아한다고 해도 될까.' → 거리: 27
# 인덱스 11774: '한 사람만 죽을 때까지 사랑하는 게 가능할까?' → 거리: 25
# 인덱스 11775: '한 사람만 죽을 때까지 사랑할 수 있을까?' → 거리: 23
# 인덱스 11776: '한 사람을 오랫동안 좋아하는게 신기하대.' → 거리: 21
# 인덱스 11777: '한쪽만 호감이면' → 거리: 8
# 인덱스 11778: '한폭의 그림 같은 우리' → 거리: 12
# 인덱스 11779: '항상 내편이 생겨서 좋아' → 거리: 13
# 인덱스 11780: '항상 여친 집 데려다줘?' → 거리: 13
# 인덱스 11781: '해외여행하다 숙소에서 만난 외국인이 너무 좋은데 이 연애 무리일까?' → 거리: 37
# 인덱스 11782: '헤어졌는데도 좋아하는거 별로임?' → 거리: 17
# 인덱스 11783: '헤어졌다가 다시 연애하는데 잘 사귈 수 있을까?' → 거리: 26
# 인덱스 11784: '헤어지고 나서 알았어 사랑했다는 걸' → 거리: 19
# 인덱스 11785: '헤어지고 얼마 안됐는데 썸타는 거 가능?' → 거리: 21
# 인덱스 11786: '헤어진 남친이랑 다시 썸타기' → 거리: 15
# 인덱스 11787: '헤어진 여자친구랑 썸부터 시작할 수 있을까' → 거리: 23
# 인덱스 11788: '헬스장에서 인사하는 사람 맘에 드는데 번호 달라고 할까?' → 거리: 31
# 인덱스 11789: '헬스장에서 자주 보는 여자가 보고싶어' → 거리: 20
# 인덱스 11790: '헷갈리는데 유지하는 게 좋을까' → 거리: 16
# 인덱스 11791: '현실적 문제로 연애 포기해야할듯' → 거리: 17
# 인덱스 11792: '혈액형이 성격이랑 무슨 상관이지' → 거리: 17
# 인덱스 11793: '호감을 표현하는 방법' → 거리: 11
# 인덱스 11794: '혼인신고 아직 안 했는데 이혼해도 될까' → 거리: 20
# 인덱스 11795: '혼인신고 하러 왔어' → 거리: 10
# 인덱스 11796: '혼인신고하니까 마음이 이상해' → 거리: 15
# 인덱스 11797: '혼자 노력하는 연애인 거 같아' → 거리: 16
# 인덱스 11798: '혼자 썸타는 기분이야.' → 거리: 12
# 인덱스 11799: '혼자 좋아하는 것 같아' → 거리: 12
# 인덱스 11800: '나만 좋아하는 것 같아' → 거리: 12
# 인덱스 11801: '혼자 좋아하는 이야기 들어 볼래요?' → 거리: 19
# 인덱스 11802: '혼자 좋아하는 이야기.' → 거리: 12
# 인덱스 11803: '혼자 좋아하는게 이렇게 힘든 적은 처음이에요.' → 거리: 25
# 인덱스 11804: '혼자가 편하다는 짝남에게 먼저 대쉬해버림.' → 거리: 23
# 인덱스 11805: '혼자가 편하다는 짝녀에게 들이댔음.' → 거리: 19
# 인덱스 11806: '혼자만 설레고 혼자서 끝내는 짝사랑 그만할래.' → 거리: 25
# 인덱스 11807: '화이트데이에 고백할까요?' → 거리: 13
# 인덱스 11808: '화장 안했는데 썸남이 영통 걸었어. 어떡해?' → 거리: 23
# 인덱스 11809: '확실히 날 좋아하는 걸 아는 남자랑 친구가 될 수 있을까?' → 거리: 32
# 인덱스 11810: '확실히 좋아하는 데도 관심 있는거 티 안내려고 선톡 안하고 일부러 늦게 보내고 그러는 사람도 있어요?' → 거리: 55
# 인덱스 11811: '홧김에 짝남한테 고백했다.' → 거리: 14
# 인덱스 11812: '회사 짝남 오빠 게임 초대 톡 옴.' → 거리: 19
# 인덱스 11813: '회사에 좋아하는 남자가 생겼어 어떡하지?' → 거리: 22
# 인덱스 11814: '회사에서 어떤 사람이랑 자꾸 눈 마추쳐.' → 거리: 22
# 인덱스 11815: '회식 중이라고 하는데 연락이 안돼.' → 거리: 18
# 인덱스 11816: '회식하는데 나만 챙겨줘. 썸임?' → 거리: 17
# 인덱스 11817: '후회 없이 사랑하고 싶어' → 거리: 13
# 인덱스 11818: '훔쳐보는 것도 눈치 보임.' → 거리: 14
# 인덱스 11819: '훔쳐보는 것도 눈치 보임.' → 거리: 14
# 인덱스 11820: '흑기사 해주는 짝남.' → 거리: 11
# 인덱스 11821: '힘든 연애 좋은 연애라는게 무슨 차이일까?' → 거리: 23
# 인덱스 11822: '힘들어서 결혼할까봐' → 거리: 10
# ============================================================
#  가장 유사한 질문 인덱스: 2949
#  가장 유사한 질문: '안녕'
#  최소 레벤슈타인 거리: 0
#
# 🎉 코랩에서 레벤슈타인 챗봇이 성공적으로 실행되었습니다!
